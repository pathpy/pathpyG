# %%
import torch

import pathpyG as pp

print('Running on', pp.config['torch']['device'])
# Out:
# Running on cuda

# %% [markdown]
# Let's create a simple path data set with four paths of length two:
#
# - 2 x A -> C -> D
# - 2 x B -> C -> E
#
# Using the following index mappings
#
# 0: A
# 1: B
# 2: C
# 3: D
# 4: E
#
# we can create these data as follows:

# %%
paths = pp.PathData()
paths.add_walk(torch.tensor([[0,2],[2,3]])) # A -> C -> D
paths.add_walk(torch.tensor([[0,2],[2,3]])) # A -> C -> D
paths.add_walk(torch.tensor([[1,2],[2,4]])) # B -> C -> E
paths.add_walk(torch.tensor([[1,2],[2,4]])) # B -> C -> E

# %%
paths.num_paths
# Out:
# 4

# %%
paths.num_nodes
# Out:
# 5

# %%
paths.num_edges
# Out:
# 8

# %%
print(paths)
# Out:
# PathStorage with 4 paths

# %% [markdown]
# We can assign features to paths

# %%
paths['path_feature'] = torch.tensor([0,1]).to(pp.config['torch']['device'])

# %%
paths.is_path_attr('path_feature')
# Out:
# True

# %% [markdown]
# Paths are internally stored in a path_index dictionary, where the key is the index of the path

# %%
paths['path_index']
# Out:
# {0: tensor([[0, 2],
#          [2, 3]]),
#  1: tensor([[0, 2],
#          [2, 3]]),
#  2: tensor([[1, 2],
#          [2, 4]]),
#  3: tensor([[1, 2],
#          [2, 4]])}

# %% [markdown]
# We can project the path_index to an edge index, which corresponds to the edge_index of all traversed edges in a graph

# %%
paths.edge_index
# Out:
# tensor([[0, 2, 0, 2, 1, 2, 1, 2],
#         [2, 3, 2, 3, 2, 4, 2, 4]])

# %% [markdown]
# We can also create a weighted edge_index with unique edges

# %%
paths.edge_index_weighted
# Out:
# (tensor([[0, 1, 2, 2],
#          [2, 2, 3, 4]]),
#  tensor([2, 2, 2, 2]))

# %% [markdown]
# This is a first-order graph representation. We can also generate k-th order representations with and without weights.
#
# A k-th order edge index with m edges has the shape [2,m,k], i.e. it consists of a src and dst tensor with m entries, where each entry is a k-dim tensor representing the k nodes that constitute the higher-order node.

# %%
paths.edge_index_k(k=2)
# Out:
# tensor([[[0, 2],
#          [0, 2],
#          [1, 2],
#          [1, 2]],
#
#         [[2, 3],
#          [2, 3],
#          [2, 4],
#          [2, 4]]])

# %%
i, w = paths.edge_index_k_weighted(k=2)
print('higher-order edges =', i)
print('weights =', w)
# Out:
# higher-order edges = tensor([[[0, 2],
#          [1, 2]],
#
#         [[2, 3],
#          [2, 4]]])
# weights = tensor([2, 2])

# %% [markdown]
# We can use paths to generate k-th order graphs that can be used for GNNs. To make access to nodes and edges convenient, we can pass a node_id mapping that assigns Ids to first-order nodes:

# %%
g = pp.HigherOrderGraph(paths, order=2, node_id=['a', 'b', 'c', 'd', 'e'])
print(g)
# Out:
# HigherOrderGraph (k=2) with 4 nodes and 2 edges
#
# Edge attributes
# 	edge_weight		<class 'torch.Tensor'> -> torch.Size([2])
#
# Graph attributes
# 	num_nodes		<class 'int'>
# 	node_id		<class 'list'>

# %% [markdown]
# Just like for a normal graph, we can iterate through nodes, which are tuples with k elements:

# %%
for n in g.nodes:
    print(n)
# Out:
# ('a', 'c')
# ('b', 'c')
# ('c', 'd')
# ('c', 'e')

# %% [markdown]
# Edges are tuples with two elements, where each element is a k-th order node:

# %%
for e in g.edges:
    print(e)
# Out:
# (('a', 'c'), ('c', 'd'))
# (('b', 'c'), ('c', 'e'))

# %% [markdown]
# The weight attribute stores tensors that capture the frequencies of edges:

# %%
print(g.data.is_edge_attr('edge_weight'))
# Out:
# True

# %%
g['edge_weight', ('a', 'c'), ('c', 'd')].item()
# Out:
# 2

# %% [markdown]
# We can also add paths with frequencies:

# %%
paths = pp.GlobalPathStorage()
paths.add_walk(torch.tensor([[0,2,3],[2,3,4]]).to(pp.config['torch']['device'])) # A -> C -> D -> E
paths.add_walk(torch.tensor([[1,2],[2,4]]).to(pp.config['torch']['device'])) # B -> C -> E
paths.add_walk(torch.tensor([[0,2],[2,3]]).to(pp.config['torch']['device'])) # A -> C -> D


paths['path_freq'] = torch.tensor([2,2,1]).to(pp.config['torch']['device'])

print(paths['path_index'])

# second-order weights: 
# (0,2), (2,3) -> 3
# (1,2), (2,4) -> 2
# (0,2), (2,3) -> 1
# Out:
# {0: tensor([[0, 2, 3],
#         [2, 3, 4]], device='cuda:0'), 1: tensor([[1, 2],
#         [2, 4]], device='cuda:0'), 2: tensor([[0, 2],
#         [2, 3]], device='cuda:0')}

# %% [markdown]
# Compute 2nd-order edges

# %%
i = torch.cat(list(pp.GlobalPathStorage.edge_index_kth_order(x, k=2) for x in paths['path_index'].values()), dim=1)
print(i)
# Out:
# tensor([[[0, 2],
#          [2, 3],
#          [1, 2],
#          [0, 2]],
#
#         [[2, 3],
#          [3, 4],
#          [2, 4],
#          [2, 3]]], device='cuda:0')

# %% [markdown]
# Compute frequencies of second-order edges based on path frequencies

# %%
freq = torch.cat(list(torch.Tensor([paths['path_freq'][idx].item()]*(paths['path_index'][idx].size()[1]-1)).to(pp.config['torch']['device']) for idx in range(paths.num_paths)), dim=0)
print(freq)
# Out:
# tensor([2., 2., 2., 1.], device='cuda:0')

# %% [markdown]
# Compute unique second-order edges + plus mapping from non-unique to unique second-order edges

# %%
edge_index, reverse_index = i.unique(dim=1, return_inverse=True)
print(edge_index)
print(reverse_index)
# Out:
# tensor([[[0, 2],
#          [1, 2],
#          [2, 3]],
#
#         [[2, 3],
#          [2, 4],
#          [3, 4]]], device='cuda:0')
# tensor([0, 2, 1, 0], device='cuda:0')

# %% [markdown]
# For each edge in the unique edge_index, x contains all indices in the non-unique edge_index i that correspond to that edge

# %%
x = list((reverse_index == idx).nonzero() for idx in range(edge_index.size()[1]))

print(x[0])
print(freq[x[0]])
print(torch.sum(freq[x[0]]))
print(x[1])
print(freq[x[1]])
print(torch.sum(freq[x[1]]))
print(x[2])
print(freq[x[2]])
print(torch.sum(freq[x[2]]))
# Out:
# tensor([[0],
#         [3]], device='cuda:0')
# tensor([[2.],
#         [1.]], device='cuda:0')
# tensor(3., device='cuda:0')
# tensor([[2]], device='cuda:0')
# tensor([[2.]], device='cuda:0')
# tensor(2., device='cuda:0')
# tensor([[1]], device='cuda:0')
# tensor([[2.]], device='cuda:0')
# tensor(2., device='cuda:0')

# %%
edge_weights = torch.tensor([torch.sum(freq[x[idx]]) for idx in range(edge_index.size()[1])])
print(edge_weights)
# Out:
# tensor([3., 2., 2.])

# %%
paths.edge_index_k_weighted(k=2)
# Out:
# (tensor([[[0, 2],
#           [1, 2],
#           [2, 3]],
#
#          [[2, 3],
#           [2, 4],
#           [3, 4]]]),
#  tensor([2, 1, 1]))

# %%
paths.edge_index_k_weighted(k=2, path_freq='path_freq')
# Out:
# (tensor([[[0, 2],
#           [1, 2],
#           [2, 3]],
#
#          [[2, 3],
#           [2, 4],
#           [3, 4]]]),
#  tensor([3., 2., 2.]))

# %%
paths.edge_index_k_weighted(k=3, path_freq='path_freq')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 paths.edge_index_k_weighted(k=3, path_freq='path_freq')
#
# File /workspaces/pathpyG/src/pathpyG/core/PathData.py:101, in PathStorage.edge_index_k_weighted(self, k, path_freq)
#      99         freq = cat(list(Tensor([self[path_freq][idx].item()]*(self['path_index'][idx].size()[1]-k+1)).to(config['torch']['device']) for idx in range(self.num_paths)), dim=0)
#     100 else:
# --> 101     i = cat(list(PathStorage.edge_index_kth_order(x, k) for x in self['path_index'].values()), dim=1)
#     102     if path_freq:
#     103         # each path with length l leads to l-k
#     104         freq = cat(list(Tensor([self[path_freq][idx].item()]*(self['path_index'][idx].size()[1]-k+1)).to(config['torch']['device']) for idx in range(self.num_paths)), dim=0)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument tensors in method wrapper_CUDA_cat)

# %% [markdown]
# We can read data from an n-gram file, where each line is a path consisting of comma-separated nodes:

# %%
p = GlobalPathStorage.from_csv('tube_paths_train.ngram')

# %%
print(p)
# Out:
# PathStorage with 61748 paths

# %%
len(p['path_freq'])
# Out:
# 61748

# %%
p.edge_index_k(k=2).size()
# Out:
# torch.Size([2, 634916, 2])

# %%
i, w = p.edge_index_k_weighted(k=2, path_freq='path_freq')
torch.sum(w)
# Out:
# tensor(12356472.)

# %%
i, w = p.edge_index_k_weighted(k=3, path_freq='path_freq')
torch.sum(w)
# Out:
# tensor(10308563.)

# %%
i, w = p.edge_index_k_weighted(k=5, path_freq='path_freq')
torch.sum(w)
# Out:
# tensor(6791043.)

# %% [markdown]
# When reading paths from a csv file, the PathStorage automatically assigns node_names and path frequencies:

# %%
print(p['node_name'])
# Out:
# ['Southwark', 'Waterloo', 'Liverpool Street', 'Bank / Monument', 'Barking', 'West Ham', 'Tufnell Park', 'Kentish Town', 'Ruislip Gardens', 'South Ruislip', 'Turnpike Lane', 'Manor House', 'Seven Sisters', 'Finsbury Park', 'Tower Hill', 'Upminster', 'Embankment', 'Temple', 'Finchley Road', 'Willesden Green', 'Angel', 'Old Street', 'Holland Park', 'Notting Hill Gate', 'Baker Street', 'Bond Street', 'Latimer Road', 'Ladbroke Grove', 'North Harrow', 'Pinner', 'Chesham', 'Chalfont & Latimer', 'Westminster', 'Turnham Green', 'Stamford Brook', 'Belsize Park', 'Chalk Farm', 'Bow Road', 'BromleyByBow', 'Woodford', 'Buckhurst Hill', 'Hanger Lane', 'North Acton', 'Vauxhall', 'Stockwell', "Shepherd's Bush (Cen)", 'White City', 'Stratford', 'Whitechapel', 'South Woodford', 'Snaresbrook', 'East Acton', 'Moorgate', 'Edgware Road (Cir)', 'Paddington', 'Caledonian Road', 'Holloway Road', 'West Brompton', "Earl's Court", 'Queensbury', 'Kingsbury', 'Loughton', 'Debden', 'Lancaster Gate', 'Marble Arch', 'Edgware Road (Bak)', "King's Cross St. Pancras", 'Euston', 'Bermondsey', 'Canada Water', 'Clapham North', 'Clapham Common', 'Lambeth North', 'Uxbridge', 'Hillingdon', 'Finchley Central', 'Mill Hill East', 'Camden Town', 'Stonebridge Park', 'Wembley Central', 'Highgate', 'East Finchley', 'Green Park', 'Piccadilly Circus', 'Archway', 'Aldgate East', 'Kilburn', 'Pimlico', 'Mornington Crescent', 'Canons Park', 'Wembley Park', 'Warwick Avenue', 'Oxford Circus', 'HarrowOnTheHill', 'West Harrow', "St. James's Park", 'Gunnersbury', 'Kew Gardens', 'Tottenham Court Road', 'Leicester Square', 'Goldhawk Road', 'Hammersmith (H&C)', 'Hounslow East', 'Osterley', 'West Hampstead', 'Royal Oak', 'Warren Street', 'Barons Court', 'Barkingside', 'Newbury Park', 'Hyde Park Corner', 'Ruislip', 'Ickenham', 'West Kensington', 'Stepney Green', 'London Bridge', 'Upminster Bridge', 'Bayswater', 'Marylebone', 'Borough', 'Elephant & Castle', 'Farringdon', 'Ealing Broadway', 'Walthamstow Central', 'Blackhorse Road', 'Covent Garden', 'Rayners Lane', 'Eastcote', 'Hammersmith (Dis)', 'Ealing Common', 'Acton Town', 'Highbury & Islington', 'South Ealing', 'Theydon Bois', 'Epping', 'Kensal Green', 'Willesden Junction', 'Tottenham Hale', 'Chigwell', 'Grange Hill', 'Canary Wharf', 'South Wimbledon', 'Morden', 'Totteridge & Whetstone', 'Woodside Park', 'Holborn', 'Neasden', 'Gants Hill', 'Elm Park', 'Hornchurch', 'South Harrow', 'Sudbury Hill', 'Richmond', 'Harlesden', 'Burnt Oak', 'Colindale', 'Upney', "St. John's Wood", 'Barbican', 'Gloucester Road', 'South Kensington', 'Leyton', 'Balham', 'Tooting Bec', 'Mile End', 'Russell Square', 'Euston Square', 'Tooting Broadway', 'Colliers Wood', 'Charing Cross', 'Wood Green', 'Bounds Green', 'Northolt', 'East Ham', 'Westbourne Park', 'West Ruislip', "St. Paul's", 'Chancery Lane', 'Clapham South', 'Arsenal', 'Wood Lane', 'Redbridge', "Queen's Park", 'Sudbury Town', 'West Acton', 'Victoria', 'Aldgate', 'Sloane Square', 'Upton Park', 'Hainault', 'Fairlop', 'Queensway', 'Rickmansworth', 'Chorleywood', 'Moor Park', 'Alperton', 'Park Royal', 'Heathrow Terminals 123', 'Heathrow Terminal 5', 'East Putney', 'Putney Bridge', 'Edgware', 'Bethnal Green', 'Hatton Cross', 'Hounslow West', 'Brixton', 'Harrow & Wealdstone', 'Kenton', 'Hendon Central', 'Brent Cross', 'High Street Kensington', 'Northfields', 'Wanstead', 'Knightsbridge', 'Wimbledon Park', 'Wimbledon', 'Amersham', 'Dagenham East', 'Cannon Street', 'Stanmore', 'Blackfriars', 'Plaistow', 'Roding Valley', 'Parsons Green', 'Greenford', 'Mansion House', 'Southfields', 'Hampstead', 'Oakwood', 'Cockfosters', 'Dagenham Heathway', 'North Ealing', 'Arnos Grove', 'Southgate', "Shepherd's Bush Market", 'Northwood Hills', "Regent's Park", 'Ravenscourt Park', 'Kilburn Park', 'Canning Town', 'North Greenwich', 'Kennington', 'Dollis Hill', 'Becontree', 'Hounslow Central', 'Golders Green', 'Goodge Street', 'Northwick Park', 'Preston Road', 'Great Portland Street', 'South Kenton', 'Heathrow Terminal 4', 'Swiss Co ...

# %%
print(p['path_freq'])
# Out:
# tensor([2.1200e+02, 1.2710e+03, 2.8300e+02,  ..., 3.0000e+00, 1.0000e+00,
#         1.0000e+00])

# %% [markdown]
# The node names can be used as node_ids in a HigherOrder Graph

# %%
g = HigherOrderGraph(p, order=2, node_id=p['node_name'], path_freq='path_freq')
print(g)
# Out:
# HigherOrderGraph (k=2) with 642 nodes and 1139 edges
#
# Edge attributes
# 	edge_weight		<class 'torch.Tensor'> -> torch.Size([1139])
#
# Graph attributes
# 	num_nodes		<class 'int'>
# 	node_id		<class 'list'>

# %%
for e in g.edges:
    print(e, g['edge_weight', e[0], e[1]].item())
# Out:
# (('Southwark', 'Waterloo'), ('Waterloo', 'Embankment')) 8405.0
# (('Southwark', 'Waterloo'), ('Waterloo', 'Westminster')) 91710.0
# (('Southwark', 'Waterloo'), ('Waterloo', 'Lambeth North')) 204.0
# (('Southwark', 'Waterloo'), ('Waterloo', 'Kennington')) 13182.0
# (('Southwark', 'London Bridge'), ('London Bridge', 'Bank / Monument')) 73218.0
# (('Southwark', 'London Bridge'), ('London Bridge', 'Bermondsey')) 51530.0
# (('Southwark', 'London Bridge'), ('London Bridge', 'Borough')) 296.0
# (('Waterloo', 'Southwark'), ('Southwark', 'London Bridge')) 140333.0
# (('Waterloo', 'Embankment'), ('Embankment', 'Temple')) 1499.0
# (('Waterloo', 'Embankment'), ('Embankment', 'Charing Cross')) 11663.0
# (('Waterloo', 'Westminster'), ('Westminster', 'Green Park')) 103374.0
# (('Waterloo', 'Westminster'), ('Westminster', "St. James's Park")) 19691.0
# (('Waterloo', 'Lambeth North'), ('Lambeth North', 'Elephant & Castle')) 3719.0
# (('Waterloo', 'Kennington'), ('Kennington', 'Elephant & Castle')) 3771.0
# (('Waterloo', 'Kennington'), ('Kennington', 'Oval')) 20312.0
# (('Liverpool Street', 'Bank / Monument'), ('Bank / Monument', 'Tower Hill')) 205.0
# (('Liverpool Street', 'Bank / Monument'), ('Bank / Monument', 'London Bridge')) 47231.0
# (('Liverpool Street', 'Bank / Monument'), ('Bank / Monument', "St. Paul's")) 47464.0
# (('Liverpool Street', 'Bank / Monument'), ('Bank / Monument', 'Cannon Street')) 2580.0
# (('Liverpool Street', 'Moorgate'), ('Moorgate', 'Old Street')) 18381.0
# (('Liverpool Street', 'Moorgate'), ('Moorgate', 'Barbican')) 23396.0
# (('Liverpool Street', 'Aldgate East'), ('Aldgate East', 'Tower Hill')) 184.0
# (('Liverpool Street', 'Aldgate East'), ('Aldgate East', 'Whitechapel')) 34708.0
# (('Liverpool Street', 'Tottenham Hale'), ('Tottenham Hale', 'Seven Sisters')) 14069.0
# (('Liverpool Street', 'Tottenham Hale'), ('Tottenham Hale', 'Blackhorse Road')) 8175.0
# (('Liverpool Street', 'Aldgate'), ('Aldgate', 'Tower Hill')) 168.0
# (('Liverpool Street', 'Bethnal Green'), ('Bethnal Green', 'Mile End')) 40307.0
# (('Bank / Monument', 'Liverpool Street'), ('Liverpool Street', 'Aldgate East')) 22329.0
# (('Bank / Monument', 'Liverpool Street'), ('Liverpool Street', 'Tottenham Hale')) 17445.0
# (('Bank / Monument', 'Liverpool Street'), ('Liverpool Street', 'Aldgate')) 748.0
# (('Bank / Monument', 'Liverpool Street'), ('Liverpool Street', 'Bethnal Green')) 30899.0
# (('Bank / Monument', 'Tower Hill'), ('Tower Hill', 'Aldgate East')) 22368.0
# (('Bank / Monument', 'Tower Hill'), ('Tower Hill', 'Aldgate')) 724.0
# (('Bank / Monument', 'Moorgate'), ('Moorgate', 'Old Street')) 22225.0
# (('Bank / Monument', 'Moorgate'), ('Moorgate', 'Barbican')) 12147.0
# (('Bank / Monument', 'London Bridge'), ('London Bridge', 'Southwark')) 77592.0
# (('Bank / Monument', 'London Bridge'), ('London Bridge', 'Bermondsey')) 8529.0
# (('Bank / Monument', 'London Bridge'), ('London Bridge', 'Borough')) 15701.0
# (('Bank / Monument', "St. Paul's"), ("St. Paul's", 'Chancery Lane')) 78212.0
# (('Bank / Monument', 'Cannon Street'), ('Cannon Street', 'Mansion House')) 5484.0
# (('Barking', 'West Ham'), ('West Ham', 'BromleyByBow')) 721.0
# (('Barking', 'West Ham'), ('West Ham', 'Stratford')) 21639.0
# (('Barking', 'West Ham'), ('West Ham', 'Plaistow')) 509.0
# (('Barking', 'West Ham'), ('West Ham', 'Canning Town')) 4412.0
# (('Barking', 'Upminster'), ('Upminster', 'Upminster Bridge')) 4084.0
# (('Barking', 'Upney'), ('Upney', 'Becontree')) 7378.0
# (('Barking', 'East Ham'), ('East Ham', 'Upton Park')) 1069.0
# (('West Ham', 'Barking'), ('Barking', 'Upminster')) 4851.0
# (('West Ham', 'Barking'), ('Barking', 'Upney')) 6709.0
# (('West Ham', 'Barking'), ('Barking', 'East Ham')) 9255.0
# (('West Ham', 'BromleyByBow'), ('BromleyByBow', 'Bow Road')) 651.0
# (('West Ham', 'Stratford'), ('Stratford', 'Whitechapel')) 21610.0
# (('West Ham', 'Stratford'), ('Stratford', 'Leyton')) 3793.0
# (('West Ham', 'Stratford'), ('Stratford', 'Mile End')) 13025.0
# (('West Ham', 'Plaistow'), ('Plaistow', 'Upton Park')) 6315.0
# (('West Ham', 'Canning Town'), ('Canning Town', 'North Greenwich')) 16617.0
# (('Tufnell Park', 'Kentish Town'), ('Kentish Town', 'Camden Town')) 27597.0
# (('Tufnell Park', 'Archway'), ('Archway', 'Highgate')) 19211.0
# (('Kentish Town', 'Tufnell Park'), ('Tufnell Park', 'Archway')) 24638.0
# (('Kentish Town', 'Camden Town'), ('Camden Town', 'Chalk Farm')) 1285.0
# (('Kentish Town', 'Camden Town'), ('Camden Town', 'Euston')) 29538.0
# (('Kentish Town', 'Camden Town'), ('Camden Town', 'Mornington Crescent')) 517.0
# (('Ruislip Gardens', 'South Ruislip'), ('South Ruislip', 'Northolt')) 837.0
# (('South Ruislip', 'Northolt'), ('Northolt', 'Greenford')) 3310.0
# (('Turnpike Lane', 'Manor House'), ('Manor House', 'Finsbury Park')) 27920.0
# (('Turnpike Lane', 'Wood Green'), ('Wood Green', 'Bounds Green')) 13387.0
# (('Manor House', 'Turnpike Lane'), ('Turnpike Lane', 'Wood Green')) 20965.0
# (('Manor House', 'Finsbury Park'), ('Finsbury Park', 'Seven Sisters')) 6624.0
# (('Manor House', 'Finsbury Park'), ('Finsbury Park', 'Highbury & Islington')) 25704.0
# (('Manor House', 'Finsbury Park'), ('Finsbury Park', 'Arsenal')) 989.0
# (('Seven Sisters', 'Finsbury Park'), ('Finsbury Park', 'Manor House')) 5926.0
# (('Seven Sisters', 'Finsbury Park'), ('Finsbury Park', 'Highbury & Islington')) 22983.0
# (('Seven Sisters', 'Finsbury Park'), ('Finsbury Park', 'Arsenal')) 1312.0
# (('Seven Sisters', 'Tottenham Hale'), ('Tottenham Hale', 'Liverpool Street')) 13034.0
# (('Seven Sisters', 'Tottenham Hale'), ('Tottenham Hale', 'Blackhorse Road')) 8234.0
# (('Finsbury Park', 'Manor House'), ('Manor House', 'Turnpike Lane')) 26982.0
# (('Finsbury Park', 'Seven Sisters'), ('Seven Sisters', 'Tottenham Hale')) 21454.0
# (('Finsbury Park', 'Highbury & Islington'), ('Highbury & Islington', "King's Cross St. Pancras")) 55407.0
# (('Finsbury Park', 'Arsenal'), ('Arsenal', 'Holloway Road')) 1902.0
# (('Tower Hill', 'Bank / Monument'), ('Bank / Monument', 'Liverpool Street')) 169.0
# (('Tower Hill', 'Bank / Monument'), ('Bank / Monument', 'Moorgate')) 1869.0
# (('Tower Hill', 'Bank / Monument'), ('Bank / Monument', 'London Bridge')) 17772.0
# (('Tower Hill', 'Bank / Monument'), ('Bank / Monument', "St. Paul's")) 15059.0
# (('Tower Hill', 'Bank / Monument'), ('Bank / Monument', 'Cannon Street')) 2826.0
# (('Tower Hill', 'Aldgate East'), ('Aldgate East', 'Liverpool Street')) 159.0
# (('Tower Hill', 'Aldgate East'), ('Aldgate East', 'Whitechapel')) 21479.0
# (('Tower Hill', 'Aldgate'), ('Aldgate', 'Liverpool Street')) 160.0
# (('Upminster', 'Barking'), ('Barking', 'West Ham')) 5150.0
# (('Upminster', 'Barking'), ('Barking', 'Upney')) 246.0
# (('Upminster', 'Barking'), ('Barking', 'East Ham')) 408.0
# (('Upminster', 'Upminster Bridge'), ('Upminster Bridge', 'Hornchurch')) 3861.0
# (('Embankment', 'Waterloo'), ('Waterloo', 'Southwark')) 7763.0
# (('Embankment', 'Waterloo'), ('Waterloo', 'Lambeth North')) 645.0
# (('Embankment', 'Waterloo'), ('Waterloo', 'Kennington')) 5064.0
# (('Embankment', 'Temple'), ('Temple', 'Blackfriars')) 10196.0
# (('Embankment', 'Westminster'), ('Westminster', 'Green Park')) 12354.0
# (('Embankment', 'Westminster'), ('Westminster', "St. James's Park")) 6660.0
# (('Embankment', 'Charing Cross'), ('Charing Cross', 'Piccadilly Circus')) 3546.0
# (('Embankment', 'Charing Cross'), ('Charing Cross', 'Leicester Square')) 7744.0
# (('Temple', 'Embankment'), ('Embankment', 'Waterloo')) 1363.0
# (('Temple', 'Embankment'), ('Embankment', 'Westminster')) 11926.0
# (('Temple', 'Embankment'), ('Embankment', 'Charing Cross')) 730.0
# (('Temple', 'Blackfriars'), ('Blackfriars', 'Mansion House')) 6764.0
# (('Finchley Road', 'Willesden Green'), ('Willesden Green', 'Kilburn')) 2830.0
# (('Finchley Road', 'Willesden Green'), ('Willesden Green', 'Neasden')) 847.0
# (('Finchley Road', 'Willesden Green'), ('Willesden Green', 'Dollis Hill')) 1664.0
# (('Finchley Road', 'Baker Street'), ('Baker Street', 'Bond Street')) 28461.0
# (('Finchley Road', 'Baker Street'), ('Baker Street', 'Edgware Road (Cir)')) 2226.0
# (('Finchley Road', 'Baker Street'), ('Baker Street', 'Marylebone')) 52.0
# (('Finchley Road', 'Baker Street'), ('Baker Street', "St. John's Wood")) 574.0
# (('Finchley Road', 'Baker Street'), ('Baker Street', "Regent's Park")) 1441.0
# (('Finchley Road', 'Baker Street'), ('Baker Street', 'Great Portland Street')) 14548.0
# (('Finchley Road', 'Wembley Park'), ('Wembley Park', 'Kingsbury')) 7588.0
# (('Finchley Road', 'Wembley Park'), ('Wembley Park', 'Neasden')) 760.0
# (('Finchley Road', 'Wembley Park'), ('Wembley Park', 'Preston Road')) 1669.0
# (('Finchley Road', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'North Harrow')) 1496.0
# (('Finchley Road', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'West Harrow')) 4891.0
# (('Finchley Road', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Marylebone')) 50.0
# (('Finchley Road', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Rickmansworth')) 1902.0
# (('Finchley Road', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Moor Park')) 1654.0
# (('Finchley Road', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Northwick Park')) 1157.0
# (('Finchley Road', 'West Hampstead'), ('West Hampstead', 'Kilburn')) 2836.0
# (('Finchley Road', 'Swiss Cottage'), ('Swiss Cottage', "St. John's Wood")) 577.0
# (('Willesden Green', 'Finchley Road'), ('Finchley Road', 'Baker Street')) 9996.0
# (('Willesden Green', 'Finchley Road'), ('Finchley Road', 'Wembley Park')) 464.0
# (('Willesden Green', 'Finchley Road'), ('Finchley Road', 'HarrowOnTheHill')) 498.0
# (('Willesden Green', 'Finchley Road'), ('Finchley Road', 'West Hampstead')) 196.0
# (('Willesden Green', 'Finchley Road'), ('Finchley Road', 'Swiss Cottage')) 430.0
# (('Willesden Green', 'Kilburn'), ('Kilburn', 'West Hampstead')) 215.0
# (('Willesden Green', 'Neasden'), ('Neasden', 'Wembley Park')) 476.0
# (('Angel', 'Old Street'), ('Old Street', 'Moorgate')) 35761.0
# (('Angel', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Caledonian Road')) 638.0
# (('Angel', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Euston')) 19434.0
# (('Angel', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Farringdon')) 9.0
# (('Angel', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Highbury & Islington')) 1221.0
# (('Angel', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Russell Square')) 1353.0
# (('Angel', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Euston Square')) 15152.0
# (('Old Street', 'Angel'), ('Angel', "King's Cross St. Pancras")) 38421.0
# (('Old Street', 'Moorgate'), ('Moorgate', 'Liverpool Street')) 17724.0
# (('Old Street', 'Moorgate'), ('Moorgate', 'Bank / Monument')) 22038.0
# (('Old Street', 'Moorgate'), ('Moorgate', 'Barbican')) 31.0
# (('Holland Park', 'Notting Hill Gate'), ('Notting Hill Gate', 'Bayswater')) 2607.0
# (('Holland Park', 'Notting Hill Gate'), ('Notting Hill Gate', 'Queensway')) 16502.0
# (('Holland Park', 'Notting Hill Gate'), ('Notting Hill Gate', 'High Street Kensington')) 2268.0
# (('Holland Park', "Shepherd's Bush (Cen)"), ("Shepherd's Bush (Cen)", 'White City')) 5513.0
# (('Notting Hill Gate', 'Holland Park'), ('Holland Park', "Shepherd's Bush (Cen)")) 18160.0
# (('Notting Hill Gate', 'Bayswater'), ('Bayswater', 'Paddington')) 15205.0
# (('Notting Hill Gate', 'Queensway'), ('Queensway', 'Lancaster Gate')) 24541.0
# (('Notting Hill Gate', 'High Street Kensington'), ('High Street Kensington', "Earl's Court")) 8833.0
# (('Notting Hill Gate', 'High Street Kensington'), ('High Street Kensington', 'Gloucester Road')) 6156.0
# (('Baker Street', 'Finchley Road'), ('Finchley Road', 'Willesden Green')) 8821.0
# (('Baker Street', 'Finchley Road'), ('Finchley Road', 'Wembley Park')) 13050.0
# (('Baker Street', 'Finchley Road'), ('Finchley Road', 'HarrowOnTheHill')) 11203.0
# (('Baker Street', 'Finchley Road'), ('Finchley Road', 'West Hampstead')) 7427.0
# (('Baker Street', 'Finchley Road'), ('Finchley Road', 'Swiss Cottage')) 2370.0
# (('Baker Street', 'Bond Street'), ('Bond Street', 'Marble Arch')) 1993.0
# (('Baker Street', 'Bond Street'), ('Bond Street', 'Green Park')) 66227.0
# (('Baker Street', 'Bond Street'), ('Bond Street', 'Oxford Circus')) 10133.0
# (('Baker Street', 'Bond Street'), ('Bond Street', 'Tottenham Court Road')) 36979.0
# (('Baker Street', 'Edgware Road (Cir)'), ('Edgware Road (Cir)', 'Paddington')) 108179.0
# (('Baker Street', 'Marylebone'), ('Marylebone', 'Edgware Road (Bak)')) 3032.0
# (('Baker Street', 'Marylebone'), ('Marylebone', 'HarrowOnTheHill')) 11174.0
# (('Baker Street', "St. John's Wood"), ("St. John's Wood", 'Swiss Cottage')) 2337.0
# (('Baker Street', "Regent's Park"), ("Regent's Park", 'Oxford Circus')) 10004.0
# (('Baker Street', 'Great Portland Street'), ('Great Portland Street', 'Euston Square')) 66193.0
# (('Bond Street', 'Baker Street'), ('Baker Street', 'Finchley Road')) 27994.0
# (('Bond Street', 'Baker Street'), ('Baker Street', 'Edgware Road (Cir)')) 57635.0
# (('Bond Street', 'Baker Street'), ('Baker Street', 'Marylebone')) 14156.0
# (('Bond Street', 'Baker Street'), ('Baker Street', "St. John's Wood")) 4623.0
# (('Bond Street', 'Baker Street'), ('Baker Street', "Regent's Park")) 11.0
# (('Bond Street', 'Baker Street'), ('Baker Street', 'Great Portland Street')) 1540.0
# (('Bond Street', 'Marble Arch'), ('Marble Arch', 'Lancaster Gate')) 30033.0
# (('Bond Street', 'Green Park'), ('Green Park', 'Westminster')) 54919.0
# (('Bond Street', 'Green Park'), ('Green Park', 'Piccadilly Circus')) 4359.0
# (('Bond Street', 'Green Park'), ('Green Park', 'Hyde Park Corner')) 4236.0
# (('Bond Street', 'Green Park'), ('Green Park', 'Victoria')) 22735.0
# (('Bond Street', 'Oxford Circus'), ('Oxford Circus', 'Piccadilly Circus')) 4405.0
# (('Bond Street', 'Oxford Circus'), ('Oxford Circus', 'Warren Street')) 5609.0
# (('Bond Street', 'Oxford Circus'), ('Oxford Circus', "Regent's Park")) 6.0
# (('Bond Street', 'Tottenham Court Road'), ('Tottenham Court Road', 'Leicester Square')) 5602.0
# (('Bond Street', 'Tottenham Court Road'), ('Tottenham Court Road', 'Holborn')) 61150.0
# (('Bond Street', 'Tottenham Court Road'), ('Tottenham Court Road', 'Goodge Street')) 1249.0
# (('Latimer Road', 'Ladbroke Grove'), ('Ladbroke Grove', 'Westbourne Park')) 9931.0
# (('Latimer Road', 'Wood Lane'), ('Wood Lane', "Shepherd's Bush Market")) 6610.0
# (('Ladbroke Grove', 'Latimer Road'), ('Latimer Road', 'Wood Lane')) 8120.0
# (('Ladbroke Grove', 'Westbourne Park'), ('Westbourne Park', 'Royal Oak')) 12491.0
# (('North Harrow', 'Pinner'), ('Pinner', 'Northwood Hills')) 520.0
# (('North Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Finchley Road')) 1654.0
# (('North Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Wembley Park')) 130.0
# (('North Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'West Harrow')) 48.0
# (('North Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Marylebone')) 1618.0
# (('North Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Rickmansworth')) 34.0
# (('North Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Moor Park')) 92.0
# (('North Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Northwick Park')) 51.0
# (('Pinner', 'North Harrow'), ('North Harrow', 'HarrowOnTheHill')) 2447.0
# (('Pinner', 'Northwood Hills'), ('Northwood Hills', 'Northwood')) 100.0
# (('Chesham', 'Chalfont & Latimer'), ('Chalfont & Latimer', 'Chorleywood')) 552.0
# (('Chesham', 'Chalfont & Latimer'), ('Chalfont & Latimer', 'Amersham')) 16.0
# (('Chalfont & Latimer', 'Chorleywood'), ('Chorleywood', 'Rickmansworth')) 2629.0
# (('Westminster', 'Waterloo'), ('Waterloo', 'Southwark')) 91242.0
# (('Westminster', 'Waterloo'), ('Waterloo', 'Lambeth North')) 4532.0
# (('Westminster', 'Waterloo'), ('Waterloo', 'Kennington')) 5593.0
# (('Westminster', 'Embankment'), ('Embankment', 'Temple')) 12612.0
# (('Westminster', 'Embankment'), ('Embankment', 'Charing Cross')) 316.0
# (('Westminster', 'Green Park'), ('Green Park', 'Bond Street')) 55338.0
# (('Westminster', 'Green Park'), ('Green Park', 'Piccadilly Circus')) 2682.0
# (('Westminster', 'Green Park'), ('Green Park', 'Oxford Circus')) 22523.0
# (('Westminster', 'Green Park'), ('Green Park', 'Hyde Park Corner')) 14042.0
# (('Westminster', 'Green Park'), ('Green Park', 'Victoria')) 21065.0
# (('Westminster', "St. James's Park"), ("St. James's Park", 'Victoria')) 21303.0
# (('Turnham Green', 'Stamford Brook'), ('Stamford Brook', 'Ravenscourt Park')) 89.0
# (('Turnham Green', 'Gunnersbury'), ('Gunnersbury', 'Kew Gardens')) 9440.0
# (('Turnham Green', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Barons Court')) 7592.0
# (('Turnham Green', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Ravenscourt Park')) 99.0
# (('Turnham Green', 'Acton Town'), ('Acton Town', 'Ealing Common')) 9792.0
# (('Turnham Green', 'Acton Town'), ('Acton Town', 'South Ealing')) 198.0
# (('Stamford Brook', 'Turnham Green'), ('Turnham Green', 'Gunnersbury')) 202.0
# (('Stamford Brook', 'Turnham Green'), ('Turnham Green', 'Hammersmith (Dis)')) 561.0
# (('Stamford Brook', 'Turnham Green'), ('Turnham Green', 'Acton Town')) 1014.0
# (('Stamford Brook', 'Turnham Green'), ('Turnham Green', 'Chiswick Park')) 5.0
# (('Stamford Brook', 'Ravenscourt Park'), ('Ravenscourt Park', 'Hammersmith (Dis)')) 574.0
# (('Belsize Park', 'Chalk Farm'), ('Chalk Farm', 'Camden Town')) 25509.0
# (('Belsize Park', 'Hampstead'), ('Hampstead', 'Golders Green')) 18504.0
# (('Chalk Farm', 'Belsize Park'), ('Belsize Park', 'Hampstead')) 20819.0
# (('Chalk Farm', 'Camden Town'), ('Camden Town', 'Kentish Town')) 1290.0
# (('Chalk Farm', 'Camden Town'), ('Camden Town', 'Euston')) 25545.0
# (('Chalk Farm', 'Camden Town'), ('Camden Town', 'Mornington Crescent')) 473.0
# (('Bow Road', 'BromleyByBow'), ('BromleyByBow', 'West Ham')) 713.0
# (('Bow Road', 'Mile End'), ('Mile End', 'Stratford')) 323.0
# (('Bow Road', 'Mile End'), ('Mile End', 'Stepney Green')) 347.0
# (('Bow Road', 'Mile End'), ('Mile End', 'Bethnal Green')) 3761.0
# (('BromleyByBow', 'West Ham'), ('West Ham', 'Barking')) 966.0
# (('BromleyByBow', 'West Ham'), ('West Ham', 'Stratford')) 199.0
# (('BromleyByBow', 'West Ham'), ('West Ham', 'Plaistow')) 205.0
# (('BromleyByBow', 'West Ham'), ('West Ham', 'Canning Town')) 62.0
# (('BromleyByBow', 'Bow Road'), ('Bow Road', 'Mile End')) 1212.0
# (('Woodford', 'Buckhurst Hill'), ('Buckhurst Hill', 'Loughton')) 6737.0
# (('Woodford', 'South Woodford'), ('South Woodford', 'Snaresbrook')) 14085.0
# (('Woodford', 'Roding Valley'), ('Roding Valley', 'Chigwell')) 2096.0
# (('Buckhurst Hill', 'Woodford'), ('Woodford', 'South Woodford')) 8354.0
# (('Buckhurst Hill', 'Woodford'), ('Woodford', 'Roding Valley')) 140.0
# (('Buckhurst Hill', 'Loughton'), ('Loughton', 'Debden')) 4344.0
# (('Hanger Lane', 'North Acton'), ('North Acton', 'East Acton')) 3666.0
# (('Hanger Lane', 'North Acton'), ('North Acton', 'West Acton')) 9393.0
# (('Hanger Lane', 'Perivale'), ('Perivale', 'Greenford')) 9000.0
# (('North Acton', 'Hanger Lane'), ('Hanger Lane', 'Perivale')) 10210.0
# (('North Acton', 'East Acton'), ('East Acton', 'White City')) 5305.0
# (('North Acton', 'West Acton'), ('West Acton', 'Ealing Broadway')) 14886.0
# (('Vauxhall', 'Stockwell'), ('Stockwell', 'Clapham North')) 21108.0
# (('Vauxhall', 'Stockwell'), ('Stockwell', 'Brixton')) 13019.0
# (('Vauxhall', 'Stockwell'), ('Stockwell', 'Oval')) 2589.0
# (('Vauxhall', 'Pimlico'), ('Pimlico', 'Victoria')) 50507.0
# (('Stockwell', 'Vauxhall'), ('Vauxhall', 'Pimlico')) 37135.0
# (('Stockwell', 'Clapham North'), ('Clapham North', 'Clapham Common')) 42065.0
# (('Stockwell', 'Oval'), ('Oval', 'Kennington')) 32144.0
# (("Shepherd's Bush (Cen)", 'Holland Park'), ('Holland Park', 'Notting Hill Gate')) 19705.0
# (("Shepherd's Bush (Cen)", 'White City'), ('White City', 'East Acton')) 3883.0
# (('White City', "Shepherd's Bush (Cen)"), ("Shepherd's Bush (Cen)", 'Holland Park')) 5814.0
# (('White City', 'East Acton'), ('East Acton', 'North Acton')) 4671.0
# (('Stratford', 'West Ham'), ('West Ham', 'Barking')) 21958.0
# (('Stratford', 'West Ham'), ('West Ham', 'BromleyByBow')) 282.0
# (('Stratford', 'West Ham'), ('West Ham', 'Plaistow')) 7936.0
# (('Stratford', 'West Ham'), ('West Ham', 'Canning Town')) 14231.0
# (('Stratford', 'Whitechapel'), ('Whitechapel', 'Aldgate East')) 55499.0
# (('Stratford', 'Whitechapel'), ('Whitechapel', 'Stepney Green')) 581.0
# (('Stratford', 'Leyton'), ('Leyton', 'Leytonstone')) 36031.0
# (('Stratford', 'Mile End'), ('Mile End', 'Bow Road')) 324.0
# (('Stratford', 'Mile End'), ('Mile End', 'Stepney Green')) 622.0
# (('Stratford', 'Mile End'), ('Mile End', 'Bethnal Green')) 36435.0
# (('Whitechapel', 'Stratford'), ('Stratford', 'West Ham')) 20404.0
# (('Whitechapel', 'Stratford'), ('Stratford', 'Leyton')) 20341.0
# (('Whitechapel', 'Stratford'), ('Stratford', 'Mile End')) 365.0
# (('Whitechapel', 'Aldgate East'), ('Aldgate East', 'Liverpool Street')) 38773.0
# (('Whitechapel', 'Aldgate East'), ('Aldgate East', 'Tower Hill')) 23609.0
# (('Whitechapel', 'Stepney Green'), ('Stepney Green', 'Mile End')) 374.0
# (('South Woodford', 'Woodford'), ('Woodford', 'Buckhurst Hill')) 7764.0
# (('South Woodford', 'Woodford'), ('Woodford', 'Roding Valley')) 1930.0
# (('South Woodford', 'Snaresbrook'), ('Snaresbrook', 'Leytonstone')) 16771.0
# (('Snaresbrook', 'South Woodford'), ('South Woodford', 'Woodford')) 12410.0
# (('Snaresbrook', 'Leytonstone'), ('Leytonstone', 'Leyton')) 18559.0
# (('Snaresbrook', 'Leytonstone'), ('Leytonstone', 'Wanstead')) 80.0
# (('East Acton', 'North Acton'), ('North Acton', 'Hanger Lane')) 3301.0
# (('East Acton', 'North Acton'), ('North Acton', 'West Acton')) 2679.0
# (('East Acton', 'White City'), ('White City', "Shepherd's Bush (Cen)")) 3938.0
# (('Moorgate', 'Liverpool Street'), ('Liverpool Street', 'Aldgate East')) 10694.0
# (('Moorgate', 'Liverpool Street'), ('Liverpool Street', 'Tottenham Hale')) 1843.0
# (('Moorgate', 'Liverpool Street'), ('Liverpool Street', 'Aldgate')) 3445.0
# (('Moorgate', 'Liverpool Street'), ('Liverpool Street', 'Bethnal Green')) 10898.0
# (('Moorgate', 'Bank / Monument'), ('Bank / Monument', 'Tower Hill')) 2081.0
# (('Moorgate', 'Bank / Monument'), ('Bank / Monument', 'London Bridge')) 29326.0
# (('Moorgate', 'Bank / Monument'), ('Bank / Monument', "St. Paul's")) 286.0
# (('Moorgate', 'Bank / Monument'), ('Bank / Monument', 'Cannon Street')) 458.0
# (('Moorgate', 'Old Street'), ('Old Street', 'Angel')) 35904.0
# (('Moorgate', 'Barbican'), ('Barbican', 'Farringdon')) 37158.0
# (('Edgware Road (Cir)', 'Baker Street'), ('Baker Street', 'Finchley Road')) 2352.0
# (('Edgware Road (Cir)', 'Baker Street'), ('Baker Street', 'Bond Street')) 63305.0
# (('Edgware Road (Cir)', 'Baker Street'), ('Baker Street', 'Marylebone')) 61.0
# (('Edgware Road (Cir)', 'Baker Street'), ('Baker Street', "St. John's Wood")) 622.0
# (('Edgware Road (Cir)', 'Baker Street'), ('Baker Street', "Regent's Park")) 7284.0
# (('Edgware Road (Cir)', 'Baker Street'), ('Baker Street', 'Great Portland Street')) 39778.0
# (('Edgware Road (Cir)', 'Paddington'), ('Paddington', 'Warwick Avenue')) 14789.0
# (('Edgware Road (Cir)', 'Paddington'), ('Paddington', 'Royal Oak')) 9889.0
# (('Edgware Road (Cir)', 'Paddington'), ('Paddington', 'Bayswater')) 8776.0
# (('Edgware Road (Cir)', 'Paddington'), ('Paddington', 'Ealing Broadway')) 47148.0
# (('Paddington', 'Edgware Road (Cir)'), ('Edgware Road (Cir)', 'Baker Street')) 112704.0
# (('Paddington', 'Edgware Road (Bak)'), ('Edgware Road (Bak)', 'Marylebone')) 4056.0
# (('Paddington', 'Warwick Avenue'), ('Warwick Avenue', 'Maida Vale')) 17006.0
# (('Paddington', 'Royal Oak'), ('Royal Oak', 'Westbourne Park')) 11878.0
# (('Paddington', 'Bayswater'), ('Bayswater', 'Notting Hill Gate')) 15714.0
# (('Paddington', 'Ealing Broadway'), ('Ealing Broadway', 'Ealing Common')) 31377.0
# (('Paddington', 'Ealing Broadway'), ('Ealing Broadway', 'West Acton')) 13398.0
# (('Caledonian Road', 'Holloway Road'), ('Holloway Road', 'Arsenal')) 1248.0
# (('Caledonian Road', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Angel')) 400.0
# (('Caledonian Road', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Euston')) 3217.0
# (('Caledonian Road', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Farringdon')) 499.0
# (('Caledonian Road', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Highbury & Islington')) 433.0
# (('Caledonian Road', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Russell Square')) 2015.0
# (('Caledonian Road', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Euston Square')) 1637.0
# (('Holloway Road', 'Caledonian Road'), ('Caledonian Road', "King's Cross St. Pancras")) 4964.0
# (('Holloway Road', 'Arsenal'), ('Arsenal', 'Finsbury Park')) 2161.0
# (('West Brompton', "Earl's Court"), ("Earl's Court", 'Barons Court')) 2506.0
# (('West Brompton', "Earl's Court"), ("Earl's Court", 'West Kensington')) 111.0
# (('West Brompton', "Earl's Court"), ("Earl's Court", 'Gloucester Road')) 19624.0
# (('West Brompton', "Earl's Court"), ("Earl's Court", 'High Street Kensington')) 6522.0
# (('West Brompton', 'Fulham Broadway'), ('Fulham Broadway', 'Parsons Green')) 19823.0
# (("Earl's Court", 'West Brompton'), ('West Brompton', 'Fulham Broadway')) 25806.0
# (("Earl's Court", 'Barons Court'), ('Barons Court', 'Hammersmith (Dis)')) 24125.0
# (("Earl's Court", 'Gloucester Road'), ('Gloucester Road', 'South Kensington')) 54595.0
# (("Earl's Court", 'High Street Kensington'), ('High Street Kensington', 'Notting Hill Gate')) 8625.0
# (('Queensbury', 'Kingsbury'), ('Kingsbury', 'Wembley Park')) 6626.0
# (('Queensbury', 'Canons Park'), ('Canons Park', 'Stanmore')) 2667.0
# (('Kingsbury', 'Queensbury'), ('Queensbury', 'Canons Park')) 4110.0
# (('Kingsbury', 'Wembley Park'), ('Wembley Park', 'Finchley Road')) 7269.0
# (('Kingsbury', 'Wembley Park'), ('Wembley Park', 'HarrowOnTheHill')) 809.0
# (('Kingsbury', 'Wembley Park'), ('Wembley Park', 'Neasden')) 622.0
# (('Kingsbury', 'Wembley Park'), ('Wembley Park', 'Preston Road')) 13.0
# (('Loughton', 'Buckhurst Hill'), ('Buckhurst Hill', 'Woodford')) 7100.0
# (('Loughton', 'Debden'), ('Debden', 'Theydon Bois')) 2632.0
# (('Debden', 'Loughton'), ('Loughton', 'Buckhurst Hill')) 4998.0
# (('Debden', 'Theydon Bois'), ('Theydon Bois', 'Epping')) 2137.0
# (('Lancaster Gate', 'Marble Arch'), ('Marble Arch', 'Bond Street')) 31949.0
# (('Lancaster Gate', 'Queensway'), ('Queensway', 'Notting Hill Gate')) 22816.0
# (('Marble Arch', 'Bond Street'), ('Bond Street', 'Baker Street')) 2162.0
# (('Marble Arch', 'Bond Street'), ('Bond Street', 'Green Park')) 7580.0
# (('Marble Arch', 'Bond Street'), ('Bond Street', 'Oxford Circus')) 6412.0
# (('Marble Arch', 'Bond Street'), ('Bond Street', 'Tottenham Court Road')) 23921.0
# (('Marble Arch', 'Lancaster Gate'), ('Lancaster Gate', 'Queensway')) 27639.0
# (('Edgware Road (Bak)', 'Paddington'), ('Paddington', 'Warwick Avenue')) 716.0
# (('Edgware Road (Bak)', 'Paddington'), ('Paddington', 'Royal Oak')) 347.0
# (('Edgware Road (Bak)', 'Paddington'), ('Paddington', 'Bayswater')) 927.0
# (('Edgware Road (Bak)', 'Paddington'), ('Paddington', 'Ealing Broadway')) 1110.0
# (('Edgware Road (Bak)', 'Marylebone'), ('Marylebone', 'Baker Street')) 3067.0
# (('Edgware Road (Bak)', 'Marylebone'), ('Marylebone', 'HarrowOnTheHill')) 2926.0
# (("King's Cross St. Pancras", 'Angel'), ('Angel', 'Old Street')) 38810.0
# (("King's Cross St. Pancras", 'Caledonian Road'), ('Caledonian Road', 'Holloway Road')) 4712.0
# (("King's Cross St. Pancras", 'Euston'), ('Euston', 'Camden Town')) 28166.0
# (("King's Cross St. Pancras", 'Euston'), ('Euston', 'Mornington Crescent')) 682.0
# (("King's Cross St. Pancras", 'Euston'), ('Euston', 'Warren Street')) 59352.0
# (("King's Cross St. Pancras", 'Farringdon'), ('Farringdon', 'Barbican')) 35056.0
# (("King's Cross St. Pancras", 'Highbury & Islington'), ('Highbury & Islington', 'Finsbury Park')) 52020.0
# (("King's Cross St. Pancras", 'Russell Square'), ('Russell Square', 'Holborn')) 18707.0
# (("King's Cross St. Pancras", 'Euston Square'), ('Euston Square', 'Great Portland Street')) 64658.0
# (('Euston', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Angel')) 19994.0
# (('Euston', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Caledonian Road')) 2765.0
# (('Euston', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Farringdon')) 13515.0
# (('Euston', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Highbury & Islington')) 32804.0
# (('Euston', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Russell Square')) 2905.0
# (('Euston', "King's Cross St. Pancras"), ("King's Cross St. Pancras", 'Euston Square')) 1810.0
# (('Euston', 'Camden Town'), ('Camden Town', 'Kentish Town')) 28733.0
# (('Euston', 'Camden Town'), ('Camden Town', 'Chalk Farm')) 24178.0
# (('Euston', 'Warren Street'), ('Warren Street', 'Oxford Circus')) 96941.0
# (('Euston', 'Warren Street'), ('Warren Street', 'Goodge Street')) 5150.0
# (('Bermondsey', 'Canada Water'), ('Canada Water', 'Canary Wharf')) 54387.0
# (('Bermondsey', 'London Bridge'), ('London Bridge', 'Southwark')) 48282.0
# (('Bermondsey', 'London Bridge'), ('London Bridge', 'Bank / Monument')) 9008.0
# (('Bermondsey', 'London Bridge'), ('London Bridge', 'Borough')) 2192.0
# (('Canada Water', 'Bermondsey'), ('Bermondsey', 'London Bridge')) 62762.0
# (('Canada Water', 'Canary Wharf'), ('Canary Wharf', 'North Greenwich')) 27856.0
# (('Clapham North', 'Stockwell'), ('Stockwell', 'Vauxhall')) 21013.0
# (('Clapham North', 'Stockwell'), ('Stockwell', 'Brixton')) 543.0
# (('Clapham North', 'Stockwell'), ('Stockwell', 'Oval')) 23152.0
# (('Clapham North', 'Clapham Common'), ('Clapham Common', 'Clapham South')) 36031.0
# (('Clapham Common', 'Clapham North'), ('Clapham North', 'Stockwell')) 42200.0
# (('Clapham Common', 'Clapham South'), ('Clapham South', 'Balham')) 31102.0
# (('Lambeth North', 'Waterloo'), ('Waterloo', 'Southwark')) 361.0
# (('Lambeth North', 'Waterloo'), ('Waterloo', 'Embankment')) 481.0
# (('Lambeth North', 'Waterloo'), ('Waterloo', 'Westminster')) 4960.0
# (('Lambeth North', 'Waterloo'), ('Waterloo', 'Kennington')) 56.0
# (('Lambeth North', 'Elephant & Castle'), ('Elephant & Castle', 'Borough')) 633.0
# (('Lambeth North', 'Elephant & Castle'), ('Elephant & Castle', 'Kennington')) 51.0
# (('Uxbridge', 'Hillingdon'), ('Hillingdon', 'Ickenham')) 5939.0
# (('Hillingdon', 'Ickenham'), ('Ickenham', 'Ruislip')) 6898.0
# (('Finchley Central', 'East Finchley'), ('East Finchley', 'Highgate')) 11663.0
# (('Finchley Central', 'West Finchley'), ('West Finchley', 'Woodside Park')) 6099.0
# (('Mill Hill East', 'Finchley Central'), ('Finchley Central', 'East Finchley')) 728.0
# (('Mill Hill East', 'Finchley Central'), ('Finchley Central', 'West Finchley')) 28.0
# (('Camden Town', 'Kentish Town'), ('Kentish Town', 'Tufnell Park')) 26200.0
# (('Camden Town', 'Chalk Farm'), ('Chalk Farm', 'Belsize Park')) 24109.0
# (('Camden Town', 'Euston'), ('Euston', "King's Cross St. Pancras")) 29570.0
# (('Camden Town', 'Euston'), ('Euston', 'Warren Street')) 33443.0
# (('Stonebridge Park', 'Wembley Central'), ('Wembley Central', 'North Wembley')) 4004.0
# (('Stonebridge Park', 'Harlesden'), ('Harlesden', 'Willesden Junction')) 9145.0
# (('Wembley Central', 'Stonebridge Park'), ('Stonebridge Park', 'Harlesden')) 7870.0
# (('Wembley Central', 'North Wembley'), ('North Wembley', 'South Kenton')) 3628.0
# (('Highgate', 'East Finchley'), ('East Finchley', 'Finchley Central')) 11538.0
# (('Highgate', 'Archway'), ('Archway', 'Tufnell Park')) 19764.0
# (('East Finchley', 'Finchley Central'), ('Finchley Central', 'Mill Hill East')) 965.0
# (('East Finchley', 'Finchley Central'), ('Finchley Central', 'West Finchley')) 6693.0
# (('East Finchley', 'Highgate'), ('Highgate', 'Archway')) 16639.0
# (('Green Park', 'Bond Street'), ('Bond Street', 'Baker Street')) 62749.0
# (('Green Park', 'Bond Street'), ('Bond Street', 'Marble Arch')) 7936.0
# (('Green Park', 'Bond Street'), ('Bond Street', 'Tottenham Court Road')) 6883.0
# (('Green Park', 'Westminster'), ('Westminster', 'Waterloo')) 102943.0
# (('Green Park', 'Westminster'), ('Westminster', 'Embankment')) 13309.0
# (('Green Park', 'Westminster'), ('Westminster', "St. James's Park")) 2012.0
# (('Green Park', 'Piccadilly Circus'), ('Piccadilly Circus', 'Leicester Square')) 8952.0
# (('Green Park', 'Piccadilly Circus'), ('Piccadilly Circus', 'Charing Cross')) 1606.0
# (('Green Park', 'Oxford Circus'), ('Oxford Circus', 'Tottenham Court Road')) 6751.0
# (('Green Park', 'Oxford Circus'), ('Oxford Circus', 'Warren Street')) 64966.0
# (('Green Park', 'Oxford Circus'), ('Oxford Circus', "Regent's Park")) 1415.0
# (('Green Park', 'Hyde Park Corner'), ('Hyde Park Corner', 'Knightsbridge')) 33614.0
# (('Green Park', 'Victoria'), ('Victoria', 'Pimlico')) 43712.0
# (('Green Park', 'Victoria'), ('Victoria', "St. James's Park")) 2087.0
# (('Green Park', 'Victoria'), ('Victoria', 'Sloane Square')) 28663.0
# (('Piccadilly Circus', 'Green Park'), ('Green Park', 'Bond Street')) 3948.0
# (('Piccadilly Circus', 'Green Park'), ('Green Park', 'Westminster')) 2945.0
# (('Piccadilly Circus', 'Green Park'), ('Green Park', 'Hyde Park Corner')) 5006.0
# (('Piccadilly Circus', 'Green Park'), ('Green Park', 'Victoria')) 9597.0
# (('Piccadilly Circus', 'Oxford Circus'), ('Oxford Circus', 'Bond Street')) 3893.0
# (('Piccadilly Circus', 'Oxford Circus'), ('Oxford Circus', 'Tottenham Court Road')) 1091.0
# (('Piccadilly Circus', 'Oxford Circus'), ('Oxford Circus', 'Warren Street')) 9933.0
# (('Piccadilly Circus', 'Oxford Circus'), ('Oxford Circus', "Regent's Park")) 3921.0
# (('Piccadilly Circus', 'Leicester Square'), ('Leicester Square', 'Tottenham Court Road')) 1128.0
# (('Piccadilly Circus', 'Leicester Square'), ('Leicester Square', 'Covent Garden')) 5216.0
# (('Piccadilly Circus', 'Charing Cross'), ('Charing Cross', 'Embankment')) 3886.0
# (('Archway', 'Tufnell Park'), ('Tufnell Park', 'Kentish Town')) 25443.0
# (('Archway', 'Highgate'), ('Highgate', 'East Finchley')) 16303.0
# (('Aldgate East', 'Liverpool Street'), ('Liverpool Street', 'Bank / Monument')) 24109.0
# (('Aldgate East', 'Liverpool Street'), ('Liverpool Street', 'Moorgate')) 12000.0
# (('Aldgate East', 'Liverpool Street'), ('Liverpool Street', 'Tottenham Hale')) 3134.0
# (('Aldgate East', 'Liverpool Street'), ('Liverpool Street', 'Aldgate')) 17.0
# (('Aldgate East', 'Liverpool Street'), ('Liverpool Street', 'Bethnal Green')) 122.0
# (('Aldgate East', 'Tower Hill'), ('Tower Hill', 'Bank / Monument')) 24013.0
# (('Aldgate East', 'Tower Hill'), ('Tower Hill', 'Aldgate')) 19.0
# (('Aldgate East', 'Whitechapel'), ('Whitechapel', 'Stratford')) 50106.0
# (('Aldgate East', 'Whitechapel'), ('Whitechapel', 'Stepney Green')) 1372.0
# (('Kilburn', 'Willesden Green'), ('Willesden Green', 'Finchley Road')) 2687.0
# (('Kilburn', 'Willesden Green'), ('Willesden Green', 'Neasden')) 323.0
# (('Kilburn', 'Willesden Green'), ('Willesden Green', 'Dollis Hill')) 39.0
# (('Kilburn', 'West Hampstead'), ('West Hampstead', 'Finchley Road')) 2738.0
# (('Pimlico', 'Vauxhall'), ('Vauxhall', 'Stockwell')) 35331.0
# (('Pimlico', 'Victoria'), ('Victoria', 'Green Park')) 45625.0
# (('Pimlico', 'Victoria'), ('Victoria', "St. James's Park")) 1696.0
# (('Pimlico', 'Victoria'), ('Victoria', 'Sloane Square')) 7374.0
# (('Mornington Crescent', 'Euston'), ('Euston', "King's Cross St. Pancras")) 684.0
# (('Mornington Crescent', 'Euston'), ('Euston', 'Warren Street')) 1707.0
# (('Mornington Crescent', 'Camden Town'), ('Camden Town', 'Kentish Town')) 411.0
# (('Mornington Crescent', 'Camden Town'), ('Camden Town', 'Chalk Farm')) 575.0
# (('Canons Park', 'Queensbury'), ('Queensbury', 'Kingsbury')) 4161.0
# (('Wembley Park', 'Finchley Road'), ('Finchley Road', 'Willesden Green')) 517.0
# (('Wembley Park', 'Finchley Road'), ('Finchley Road', 'Baker Street')) 12865.0
# (('Wembley Park', 'Finchley Road'), ('Finchley Road', 'West Hampstead')) 759.0
# (('Wembley Park', 'Finchley Road'), ('Finchley Road', 'Swiss Cottage')) 527.0
# (('Wembley Park', 'Kingsbury'), ('Kingsbury', 'Queensbury')) 6556.0
# (('Wembley Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'North Harrow')) 241.0
# (('Wembley Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'West Harrow')) 1090.0
# (('Wembley Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Marylebone')) 450.0
# (('Wembley Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Rickmansworth')) 83.0
# (('Wembley Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Moor Park')) 219.0
# (('Wembley Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Northwick Park')) 98.0
# (('Wembley Park', 'Neasden'), ('Neasden', 'Willesden Green')) 551.0
# (('Wembley Park', 'Neasden'), ('Neasden', 'Dollis Hill')) 392.0
# (('Wembley Park', 'Preston Road'), ('Preston Road', 'Northwick Park')) 110.0
# (('Warwick Avenue', 'Paddington'), ('Paddington', 'Edgware Road (Cir)')) 17945.0
# (('Warwick Avenue', 'Paddington'), ('Paddington', 'Edgware Road (Bak)')) 1095.0
# (('Warwick Avenue', 'Paddington'), ('Paddington', 'Royal Oak')) 126.0
# (('Warwick Avenue', 'Paddington'), ('Paddington', 'Bayswater')) 1356.0
# (('Warwick Avenue', 'Paddington'), ('Paddington', 'Ealing Broadway')) 1178.0
# (('Warwick Avenue', 'Maida Vale'), ('Maida Vale', 'Kilburn Park')) 15322.0
# (('Oxford Circus', 'Bond Street'), ('Bond Street', 'Baker Street')) 9769.0
# (('Oxford Circus', 'Bond Street'), ('Bond Street', 'Marble Arch')) 6238.0
# (('Oxford Circus', 'Green Park'), ('Green Park', 'Westminster')) 21681.0
# (('Oxford Circus', 'Green Park'), ('Green Park', 'Hyde Park Corner')) 11257.0
# (('Oxford Circus', 'Green Park'), ('Green Park', 'Victoria')) 58208.0
# (('Oxford Circus', 'Piccadilly Circus'), ('Piccadilly Circus', 'Leicester Square')) 1632.0
# (('Oxford Circus', 'Piccadilly Circus'), ('Piccadilly Circus', 'Charing Cross')) 6595.0
# (('Oxford Circus', 'Tottenham Court Road'), ('Tottenham Court Road', 'Leicester Square')) 1635.0
# (('Oxford Circus', 'Tottenham Court Road'), ('Tottenham Court Road', 'Holborn')) 17065.0
# (('Oxford Circus', 'Tottenham Court Road'), ('Tottenham Court Road', 'Goodge Street')) 759.0
# (('Oxford Circus', 'Warren Street'), ('Warren Street', 'Euston')) 89747.0
# (('Oxford Circus', 'Warren Street'), ('Warren Street', 'Goodge Street')) 791.0
# (('Oxford Circus', "Regent's Park"), ("Regent's Park", 'Baker Street')) 9780.0
# (('HarrowOnTheHill', 'Finchley Road'), ('Finchley Road', 'Willesden Green')) 474.0
# (('HarrowOnTheHill', 'Finchley Road'), ('Finchley Road', 'Baker Street')) 11136.0
# (('HarrowOnTheHill', 'Finchley Road'), ('Finchley Road', 'West Hampstead')) 519.0
# (('HarrowOnTheHill', 'Finchley Road'), ('Finchley Road', 'Swiss Cottage')) 313.0
# (('HarrowOnTheHill', 'North Harrow'), ('North Harrow', 'Pinner')) 2347.0
# (('HarrowOnTheHill', 'Wembley Park'), ('Wembley Park', 'Kingsbury')) 641.0
# (('HarrowOnTheHill', 'Wembley Park'), ('Wembley Park', 'Neasden')) 385.0
# (('HarrowOnTheHill', 'Wembley Park'), ('Wembley Park', 'Preston Road')) 209.0
# (('HarrowOnTheHill', 'West Harrow'), ('West Harrow', 'Rayners Lane')) 12465.0
# (('HarrowOnTheHill', 'Marylebone'), ('Marylebone', 'Baker Street')) 11144.0
# (('HarrowOnTheHill', 'Marylebone'), ('Marylebone', 'Edgware Road (Bak)')) 2823.0
# (('HarrowOnTheHill', 'Rickmansworth'), ('Rickmansworth', 'Chorleywood')) 2898.0
# (('HarrowOnTheHill', 'Moor Park'), ('Moor Park', 'Croxley')) 1663.0
# (('HarrowOnTheHill', 'Moor Park'), ('Moor Park', 'Northwood')) 2096.0
# (('HarrowOnTheHill', 'Northwick Park'), ('Northwick Park', 'Preston Road')) 206.0
# (('West Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Finchley Road')) 4629.0
# (('West Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'North Harrow')) 21.0
# (('West Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Wembley Park')) 882.0
# (('West Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Marylebone')) 5338.0
# (('West Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Rickmansworth')) 95.0
# (('West Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Moor Park')) 185.0
# (('West Harrow', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Northwick Park')) 382.0
# (('West Harrow', 'Rayners Lane'), ('Rayners Lane', 'Eastcote')) 8469.0
# (('West Harrow', 'Rayners Lane'), ('Rayners Lane', 'South Harrow')) 1783.0
# (("St. James's Park", 'Westminster'), ('Westminster', 'Waterloo')) 21202.0
# (("St. James's Park", 'Westminster'), ('Westminster', 'Embankment')) 6233.0
# (("St. James's Park", 'Westminster'), ('Westminster', 'Green Park')) 1920.0
# (("St. James's Park", 'Victoria'), ('Victoria', 'Green Park')) 1907.0
# (("St. James's Park", 'Victoria'), ('Victoria', 'Pimlico')) 1164.0
# (("St. James's Park", 'Victoria'), ('Victoria', 'Sloane Square')) 14258.0
# (('Gunnersbury', 'Turnham Green'), ('Turnham Green', 'Stamford Brook')) 231.0
# (('Gunnersbury', 'Turnham Green'), ('Turnham Green', 'Hammersmith (Dis)')) 5887.0
# (('Gunnersbury', 'Turnham Green'), ('Turnham Green', 'Acton Town')) 6911.0
# (('Gunnersbury', 'Turnham Green'), ('Turnham Green', 'Chiswick Park')) 2.0
# (('Gunnersbury', 'Kew Gardens'), ('Kew Gardens', 'Richmond')) 7636.0
# (('Kew Gardens', 'Gunnersbury'), ('Gunnersbury', 'Turnham Green')) 9636.0
# (('Tottenham Court Road', 'Bond Street'), ('Bond Street', 'Baker Street')) 34389.0
# (('Tottenham Court Road', 'Bond Street'), ('Bond Street', 'Marble Arch')) 21254.0
# (('Tottenham Court Road', 'Bond Street'), ('Bond Street', 'Green Park')) 6875.0
# (('Tottenham Court Road', 'Oxford Circus'), ('Oxford Circus', 'Green Park')) 6903.0
# (('Tottenham Court Road', 'Oxford Circus'), ('Oxford Circus', 'Piccadilly Circus')) 1305.0
# (('Tottenham Court Road', 'Oxford Circus'), ('Oxford Circus', 'Warren Street')) 3029.0
# (('Tottenham Court Road', 'Oxford Circus'), ('Oxford Circus', "Regent's Park")) 144.0
# (('Tottenham Court Road', 'Leicester Square'), ('Leicester Square', 'Piccadilly Circus')) 1254.0
# (('Tottenham Court Road', 'Leicester Square'), ('Leicester Square', 'Covent Garden')) 1823.0
# (('Tottenham Court Road', 'Leicester Square'), ('Leicester Square', 'Charing Cross')) 4239.0
# (('Tottenham Court Road', 'Holborn'), ('Holborn', 'Covent Garden')) 1872.0
# (('Tottenham Court Road', 'Holborn'), ('Holborn', 'Russell Square')) 8788.0
# (('Tottenham Court Road', 'Holborn'), ('Holborn', 'Chancery Lane')) 72938.0
# (('Tottenham Court Road', 'Goodge Street'), ('Goodge Street', 'Warren Street')) 3005.0
# (('Leicester Square', 'Piccadilly Circus'), ('Piccadilly Circus', 'Green Park')) 7951.0
# (('Leicester Square', 'Piccadilly Circus'), ('Piccadilly Circus', 'Oxford Circus')) 1596.0
# (('Leicester Square', 'Tottenham Court Road'), ('Tottenham Court Road', 'Bond Street')) 5480.0
# (('Leicester Square', 'Tottenham Court Road'), ('Tottenham Court Road', 'Oxford Circus')) 1673.0
# (('Leicester Square', 'Tottenham Court Road'), ('Tottenham Court Road', 'Holborn')) 5343.0
# (('Leicester Square', 'Tottenham Court Road'), ('Tottenham Court Road', 'Goodge Street')) 2577.0
# (('Leicester Square', 'Covent Garden'), ('Covent Garden', 'Holborn')) 5339.0
# (('Leicester Square', 'Charing Cross'), ('Charing Cross', 'Embankment')) 7422.0
# (('Goldhawk Road', "Shepherd's Bush Market"), ("Shepherd's Bush Market", 'Wood Lane')) 6265.0
# (('Hammersmith (H&C)', 'Goldhawk Road'), ('Goldhawk Road', "Shepherd's Bush Market")) 5054.0
# (('Hounslow East', 'Osterley'), ('Osterley', 'Boston Manor')) 17605.0
# (('Hounslow East', 'Hounslow Central'), ('Hounslow Central', 'Hounslow West')) 11550.0
# (('Osterley', 'Hounslow East'), ('Hounslow East', 'Hounslow Central')) 13131.0
# (('Osterley', 'Boston Manor'), ('Boston Manor', 'Northfields')) 18883.0
# (('West Hampstead', 'Finchley Road'), ('Finchley Road', 'Willesden Green')) 181.0
# (('West Hampstead', 'Finchley Road'), ('Finchley Road', 'Baker Street')) 8227.0
# (('West Hampstead', 'Finchley Road'), ('Finchley Road', 'Wembley Park')) 650.0
# (('West Hampstead', 'Finchley Road'), ('Finchley Road', 'HarrowOnTheHill')) 388.0
# (('West Hampstead', 'Finchley Road'), ('Finchley Road', 'Swiss Cottage')) 331.0
# (('West Hampstead', 'Kilburn'), ('Kilburn', 'Willesden Green')) 180.0
# (('Royal Oak', 'Paddington'), ('Paddington', 'Edgware Road (Cir)')) 11631.0
# (('Royal Oak', 'Paddington'), ('Paddington', 'Edgware Road (Bak)')) 681.0
# (('Royal Oak', 'Paddington'), ('Paddington', 'Warwick Avenue')) 119.0
# (('Royal Oak', 'Paddington'), ('Paddington', 'Bayswater')) 434.0
# (('Royal Oak', 'Paddington'), ('Paddington', 'Ealing Broadway')) 1277.0
# (('Royal Oak', 'Westbourne Park'), ('Westbourne Park', 'Ladbroke Grove')) 10803.0
# (('Warren Street', 'Euston'), ('Euston', "King's Cross St. Pancras")) 52969.0
# (('Warren Street', 'Euston'), ('Euston', 'Camden Town')) 33502.0
# (('Warren Street', 'Euston'), ('Euston', 'Mornington Crescent')) 1386.0
# (('Warren Street', 'Oxford Circus'), ('Oxford Circus', 'Bond Street')) 5834.0
# (('Warren Street', 'Oxford Circus'), ('Oxford Circus', 'Green Park')) 70077.0
# (('Warren Street', 'Oxford Circus'), ('Oxford Circus', 'Piccadilly Circus')) 9160.0
# (('Warren Street', 'Oxford Circus'), ('Oxford Circus', 'Tottenham Court Road')) 3084.0
# (('Warren Street', 'Oxford Circus'), ('Oxford Circus', "Regent's Park")) 2239.0
# (('Warren Street', 'Goodge Street'), ('Goodge Street', 'Tottenham Court Road')) 3078.0
# (('Barons Court', "Earl's Court"), ("Earl's Court", 'West Brompton')) 2643.0
# (('Barons Court', "Earl's Court"), ("Earl's Court", 'Gloucester Road')) 25122.0
# (('Barons Court', "Earl's Court"), ("Earl's Court", 'High Street Kensington')) 989.0
# (('Barons Court', "Earl's Court"), ("Earl's Court", 'Kensington (Olympia)')) 61.0
# (('Barons Court', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Turnham Green')) 6491.0
# (('Barons Court', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Acton Town')) 8431.0
# (('Barons Court', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Ravenscourt Park')) 1802.0
# (('Barkingside', 'Newbury Park'), ('Newbury Park', 'Gants Hill')) 2893.0
# (('Barkingside', 'Fairlop'), ('Fairlop', 'Hainault')) 1205.0
# (('Newbury Park', 'Barkingside'), ('Barkingside', 'Fairlop')) 1905.0
# (('Newbury Park', 'Gants Hill'), ('Gants Hill', 'Redbridge')) 6420.0
# (('Hyde Park Corner', 'Green Park'), ('Green Park', 'Bond Street')) 3687.0
# (('Hyde Park Corner', 'Green Park'), ('Green Park', 'Westminster')) 15703.0
# (('Hyde Park Corner', 'Green Park'), ('Green Park', 'Piccadilly Circus')) 6126.0
# (('Hyde Park Corner', 'Green Park'), ('Green Park', 'Oxford Circus')) 11137.0
# (('Hyde Park Corner', 'Green Park'), ('Green Park', 'Victoria')) 674.0
# (('Hyde Park Corner', 'Knightsbridge'), ('Knightsbridge', 'South Kensington')) 23802.0
# (('Ruislip', 'Ickenham'), ('Ickenham', 'Hillingdon')) 6732.0
# (('Ruislip', 'Ruislip Manor'), ('Ruislip Manor', 'Eastcote')) 7806.0
# (('Ickenham', 'Hillingdon'), ('Hillingdon', 'Uxbridge')) 5778.0
# (('Ickenham', 'Ruislip'), ('Ruislip', 'Ruislip Manor')) 7220.0
# (('West Kensington', "Earl's Court"), ("Earl's Court", 'West Brompton')) 73.0
# (('West Kensington', "Earl's Court"), ("Earl's Court", 'Gloucester Road')) 2406.0
# (('West Kensington', "Earl's Court"), ("Earl's Court", 'High Street Kensington')) 495.0
# (('West Kensington', 'Barons Court'), ('Barons Court', 'Hammersmith (Dis)')) 1018.0
# (('Stepney Green', 'Whitechapel'), ('Whitechapel', 'Stratford')) 557.0
# (('Stepney Green', 'Whitechapel'), ('Whitechapel', 'Aldgate East')) 1679.0
# (('Stepney Green', 'Mile End'), ('Mile End', 'Bow Road')) 260.0
# (('Stepney Green', 'Mile End'), ('Mile End', 'Stratford')) 579.0
# (('Stepney Green', 'Mile End'), ('Mile End', 'Bethnal Green')) 942.0
# (('London Bridge', 'Southwark'), ('Southwark', 'Waterloo')) 144668.0
# (('London Bridge', 'Bank / Monument'), ('Bank / Monument', 'Liverpool Street')) 46250.0
# (('London Bridge', 'Bank / Monument'), ('Bank / Monument', 'Tower Hill')) 17293.0
# (('London Bridge', 'Bank / Monument'), ('Bank / Monument', 'Moorgate')) 28818.0
# (('London Bridge', 'Bank / Monument'), ('Bank / Monument', "St. Paul's")) 5678.0
# (('London Bridge', 'Bank / Monument'), ('Bank / Monument', 'Cannon Street')) 1063.0
# (('London Bridge', 'Bermondsey'), ('Bermondsey', 'Canada Water')) 65044.0
# (('London Bridge', 'Borough'), ('Borough', 'Elephant & Castle')) 18271.0
# (('Upminster Bridge', 'Upminster'), ('Upminster', 'Barking')) 4293.0
# (('Upminster Bridge', 'Hornchurch'), ('Hornchurch', 'Elm Park')) 2074.0
# (('Bayswater', 'Notting Hill Gate'), ('Notting Hill Gate', 'Holland Park')) 2097.0
# (('Bayswater', 'Notting Hill Gate'), ('Notting Hill Gate', 'Queensway')) 301.0
# (('Bayswater', 'Notting Hill Gate'), ('Notting Hill Gate', 'High Street Kensington')) 12212.0
# (('Bayswater', 'Paddington'), ('Paddington', 'Edgware Road (Cir)')) 8627.0
# (('Bayswater', 'Paddington'), ('Paddington', 'Edgware Road (Bak)')) 985.0
# (('Bayswater', 'Paddington'), ('Paddington', 'Warwick Avenue')) 1323.0
# (('Bayswater', 'Paddington'), ('Paddington', 'Royal Oak')) 421.0
# (('Bayswater', 'Paddington'), ('Paddington', 'Ealing Broadway')) 3300.0
# ...
# (('Moor Park', 'Croxley'), ('Croxley', 'Watford')) 1218.0
# (('Moor Park', 'Northwood'), ('Northwood', 'Northwood Hills')) 755.0
# (('Alperton', 'Sudbury Town'), ('Sudbury Town', 'Sudbury Hill')) 2570.0
# (('Alperton', 'Park Royal'), ('Park Royal', 'North Ealing')) 4955.0
# (('Park Royal', 'Alperton'), ('Alperton', 'Sudbury Town')) 2808.0
# (('Park Royal', 'North Ealing'), ('North Ealing', 'Ealing Common')) 5652.0
# (('Heathrow Terminals 123', 'Hatton Cross'), ('Hatton Cross', 'Hounslow West')) 8055.0
# (('Heathrow Terminal 5', 'Heathrow Terminals 123'), ('Heathrow Terminals 123', 'Hatton Cross')) 2729.0
# (('East Putney', 'Putney Bridge'), ('Putney Bridge', 'Parsons Green')) 15318.0
# (('East Putney', 'Southfields'), ('Southfields', 'Wimbledon Park')) 8399.0
# (('Putney Bridge', 'East Putney'), ('East Putney', 'Southfields')) 11045.0
# (('Putney Bridge', 'Parsons Green'), ('Parsons Green', 'Fulham Broadway')) 17898.0
# (('Edgware', 'Burnt Oak'), ('Burnt Oak', 'Colindale')) 3300.0
# (('Bethnal Green', 'Liverpool Street'), ('Liverpool Street', 'Bank / Monument')) 33559.0
# (('Bethnal Green', 'Liverpool Street'), ('Liverpool Street', 'Moorgate')) 11915.0
# (('Bethnal Green', 'Liverpool Street'), ('Liverpool Street', 'Aldgate East')) 164.0
# (('Bethnal Green', 'Liverpool Street'), ('Liverpool Street', 'Tottenham Hale')) 2631.0
# (('Bethnal Green', 'Liverpool Street'), ('Liverpool Street', 'Aldgate')) 64.0
# (('Bethnal Green', 'Mile End'), ('Mile End', 'Bow Road')) 3733.0
# (('Bethnal Green', 'Mile End'), ('Mile End', 'Stratford')) 33508.0
# (('Bethnal Green', 'Mile End'), ('Mile End', 'Stepney Green')) 838.0
# (('Hatton Cross', 'Heathrow Terminals 123'), ('Heathrow Terminals 123', 'Heathrow Terminal 5')) 2203.0
# (('Hatton Cross', 'Hounslow West'), ('Hounslow West', 'Hounslow Central')) 11380.0
# (('Hounslow West', 'Hatton Cross'), ('Hatton Cross', 'Heathrow Terminals 123')) 6952.0
# (('Hounslow West', 'Hatton Cross'), ('Hatton Cross', 'Heathrow Terminal 4')) 1390.0
# (('Hounslow West', 'Hounslow Central'), ('Hounslow Central', 'Hounslow East')) 13000.0
# (('Brixton', 'Stockwell'), ('Stockwell', 'Vauxhall')) 14004.0
# (('Brixton', 'Stockwell'), ('Stockwell', 'Clapham North')) 534.0
# (('Brixton', 'Stockwell'), ('Stockwell', 'Oval')) 4931.0
# (('Harrow & Wealdstone', 'Kenton'), ('Kenton', 'South Kenton')) 2842.0
# (('Kenton', 'South Kenton'), ('South Kenton', 'North Wembley')) 4199.0
# (('Hendon Central', 'Colindale'), ('Colindale', 'Burnt Oak')) 5780.0
# (('Hendon Central', 'Brent Cross'), ('Brent Cross', 'Golders Green')) 13615.0
# (('Brent Cross', 'Hendon Central'), ('Hendon Central', 'Colindale')) 7986.0
# (('Brent Cross', 'Golders Green'), ('Golders Green', 'Hampstead')) 14209.0
# (('High Street Kensington', 'Notting Hill Gate'), ('Notting Hill Gate', 'Holland Park')) 2225.0
# (('High Street Kensington', 'Notting Hill Gate'), ('Notting Hill Gate', 'Bayswater')) 11861.0
# (('High Street Kensington', 'Notting Hill Gate'), ('Notting Hill Gate', 'Queensway')) 1895.0
# (('High Street Kensington', "Earl's Court"), ("Earl's Court", 'West Brompton')) 6501.0
# (('High Street Kensington', "Earl's Court"), ("Earl's Court", 'Barons Court')) 997.0
# (('High Street Kensington', "Earl's Court"), ("Earl's Court", 'West Kensington')) 349.0
# (('High Street Kensington', "Earl's Court"), ("Earl's Court", 'Kensington (Olympia)')) 137.0
# (('High Street Kensington', 'Gloucester Road'), ('Gloucester Road', 'South Kensington')) 9717.0
# (('Northfields', 'South Ealing'), ('South Ealing', 'Acton Town')) 22272.0
# (('Northfields', 'Boston Manor'), ('Boston Manor', 'Osterley')) 17118.0
# (('Wanstead', 'Redbridge'), ('Redbridge', 'Gants Hill')) 9593.0
# (('Wanstead', 'Leytonstone'), ('Leytonstone', 'Snaresbrook')) 196.0
# (('Wanstead', 'Leytonstone'), ('Leytonstone', 'Leyton')) 13971.0
# (('Knightsbridge', 'Hyde Park Corner'), ('Hyde Park Corner', 'Green Park')) 36327.0
# (('Knightsbridge', 'South Kensington'), ('South Kensington', 'Gloucester Road')) 19345.0
# (('Knightsbridge', 'South Kensington'), ('South Kensington', 'Sloane Square')) 600.0
# (('Wimbledon Park', 'Southfields'), ('Southfields', 'East Putney')) 9455.0
# (('Wimbledon', 'Wimbledon Park'), ('Wimbledon Park', 'Southfields')) 9206.0
# (('Amersham', 'Chalfont & Latimer'), ('Chalfont & Latimer', 'Chesham')) 2.0
# (('Amersham', 'Chalfont & Latimer'), ('Chalfont & Latimer', 'Chorleywood')) 1353.0
# (('Dagenham East', 'Elm Park'), ('Elm Park', 'Hornchurch')) 215.0
# (('Dagenham East', 'Dagenham Heathway'), ('Dagenham Heathway', 'Becontree')) 1861.0
# (('Cannon Street', 'Bank / Monument'), ('Bank / Monument', 'Liverpool Street')) 2214.0
# (('Cannon Street', 'Bank / Monument'), ('Bank / Monument', 'Tower Hill')) 2570.0
# (('Cannon Street', 'Bank / Monument'), ('Bank / Monument', 'Moorgate')) 365.0
# (('Cannon Street', 'Bank / Monument'), ('Bank / Monument', 'London Bridge')) 1122.0
# (('Cannon Street', 'Bank / Monument'), ('Bank / Monument', "St. Paul's")) 560.0
# (('Cannon Street', 'Mansion House'), ('Mansion House', 'Blackfriars')) 6204.0
# (('Stanmore', 'Canons Park'), ('Canons Park', 'Queensbury')) 2569.0
# (('Blackfriars', 'Temple'), ('Temple', 'Embankment')) 10189.0
# (('Blackfriars', 'Mansion House'), ('Mansion House', 'Cannon Street')) 4996.0
# (('Plaistow', 'West Ham'), ('West Ham', 'Barking')) 471.0
# (('Plaistow', 'West Ham'), ('West Ham', 'BromleyByBow')) 217.0
# (('Plaistow', 'West Ham'), ('West Ham', 'Stratford')) 9431.0
# (('Plaistow', 'West Ham'), ('West Ham', 'Canning Town')) 1711.0
# (('Plaistow', 'Upton Park'), ('Upton Park', 'East Ham')) 226.0
# (('Roding Valley', 'Woodford'), ('Woodford', 'Buckhurst Hill')) 147.0
# (('Roding Valley', 'Woodford'), ('Woodford', 'South Woodford')) 2057.0
# (('Roding Valley', 'Chigwell'), ('Chigwell', 'Grange Hill')) 1731.0
# (('Parsons Green', 'Putney Bridge'), ('Putney Bridge', 'East Putney')) 13626.0
# (('Parsons Green', 'Fulham Broadway'), ('Fulham Broadway', 'West Brompton')) 21231.0
# (('Greenford', 'Northolt'), ('Northolt', 'South Ruislip')) 2892.0
# (('Greenford', 'Perivale'), ('Perivale', 'Hanger Lane')) 9404.0
# (('Mansion House', 'Cannon Street'), ('Cannon Street', 'Bank / Monument')) 4715.0
# (('Mansion House', 'Blackfriars'), ('Blackfriars', 'Temple')) 7272.0
# (('Southfields', 'East Putney'), ('East Putney', 'Putney Bridge')) 12207.0
# (('Southfields', 'Wimbledon Park'), ('Wimbledon Park', 'Wimbledon')) 8425.0
# (('Hampstead', 'Belsize Park'), ('Belsize Park', 'Chalk Farm')) 21607.0
# (('Hampstead', 'Golders Green'), ('Golders Green', 'Brent Cross')) 13901.0
# (('Oakwood', 'Southgate'), ('Southgate', 'Arnos Grove')) 3294.0
# (('Cockfosters', 'Oakwood'), ('Oakwood', 'Southgate')) 1364.0
# (('Dagenham Heathway', 'Dagenham East'), ('Dagenham East', 'Elm Park')) 214.0
# (('Dagenham Heathway', 'Becontree'), ('Becontree', 'Upney')) 5716.0
# (('North Ealing', 'Ealing Common'), ('Ealing Common', 'Ealing Broadway')) 1020.0
# (('North Ealing', 'Ealing Common'), ('Ealing Common', 'Acton Town')) 4523.0
# (('North Ealing', 'Park Royal'), ('Park Royal', 'Alperton')) 4307.0
# (('Arnos Grove', 'Bounds Green'), ('Bounds Green', 'Wood Green')) 9987.0
# (('Arnos Grove', 'Southgate'), ('Southgate', 'Oakwood')) 3047.0
# (('Southgate', 'Oakwood'), ('Oakwood', 'Cockfosters')) 1413.0
# (('Southgate', 'Arnos Grove'), ('Arnos Grove', 'Bounds Green')) 6979.0
# (("Shepherd's Bush Market", 'Goldhawk Road'), ('Goldhawk Road', 'Hammersmith (H&C)')) 4050.0
# (("Shepherd's Bush Market", 'Wood Lane'), ('Wood Lane', 'Latimer Road')) 8097.0
# (('Northwood Hills', 'Pinner'), ('Pinner', 'North Harrow')) 526.0
# (('Northwood Hills', 'Northwood'), ('Northwood', 'Moor Park')) 731.0
# (("Regent's Park", 'Baker Street'), ('Baker Street', 'Finchley Road')) 1506.0
# (("Regent's Park", 'Baker Street'), ('Baker Street', 'Edgware Road (Cir)')) 7178.0
# (("Regent's Park", 'Baker Street'), ('Baker Street', 'Marylebone')) 1403.0
# (("Regent's Park", 'Baker Street'), ('Baker Street', "St. John's Wood")) 177.0
# (("Regent's Park", 'Baker Street'), ('Baker Street', 'Great Portland Street')) 26.0
# (("Regent's Park", 'Oxford Circus'), ('Oxford Circus', 'Green Park')) 1183.0
# (("Regent's Park", 'Oxford Circus'), ('Oxford Circus', 'Piccadilly Circus')) 3694.0
# (("Regent's Park", 'Oxford Circus'), ('Oxford Circus', 'Tottenham Court Road')) 301.0
# (("Regent's Park", 'Oxford Circus'), ('Oxford Circus', 'Warren Street')) 1665.0
# (('Ravenscourt Park', 'Stamford Brook'), ('Stamford Brook', 'Turnham Green')) 111.0
# (('Ravenscourt Park', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Turnham Green')) 103.0
# (('Ravenscourt Park', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Barons Court')) 2033.0
# (('Ravenscourt Park', 'Hammersmith (Dis)'), ('Hammersmith (Dis)', 'Acton Town')) 586.0
# (('Kilburn Park', "Queen's Park"), ("Queen's Park", 'Kensal Green')) 9950.0
# (('Kilburn Park', 'Maida Vale'), ('Maida Vale', 'Warwick Avenue')) 18624.0
# (('Canning Town', 'West Ham'), ('West Ham', 'Barking')) 4186.0
# (('Canning Town', 'West Ham'), ('West Ham', 'BromleyByBow')) 61.0
# (('Canning Town', 'West Ham'), ('West Ham', 'Stratford')) 14809.0
# (('Canning Town', 'West Ham'), ('West Ham', 'Plaistow')) 1276.0
# (('Canning Town', 'North Greenwich'), ('North Greenwich', 'Canary Wharf')) 26019.0
# (('North Greenwich', 'Canary Wharf'), ('Canary Wharf', 'Canada Water')) 26152.0
# (('North Greenwich', 'Canning Town'), ('Canning Town', 'West Ham')) 16016.0
# (('Kennington', 'Waterloo'), ('Waterloo', 'Southwark')) 13463.0
# (('Kennington', 'Waterloo'), ('Waterloo', 'Embankment')) 4645.0
# (('Kennington', 'Waterloo'), ('Waterloo', 'Westminster')) 6044.0
# (('Kennington', 'Waterloo'), ('Waterloo', 'Lambeth North')) 45.0
# (('Kennington', 'Elephant & Castle'), ('Elephant & Castle', 'Lambeth North')) 50.0
# (('Kennington', 'Elephant & Castle'), ('Elephant & Castle', 'Borough')) 14437.0
# (('Kennington', 'Oval'), ('Oval', 'Stockwell')) 32598.0
# (('Dollis Hill', 'Willesden Green'), ('Willesden Green', 'Finchley Road')) 2230.0
# (('Dollis Hill', 'Willesden Green'), ('Willesden Green', 'Kilburn')) 95.0
# (('Dollis Hill', 'Neasden'), ('Neasden', 'Wembley Park')) 563.0
# (('Becontree', 'Upney'), ('Upney', 'Barking')) 7703.0
# (('Becontree', 'Dagenham Heathway'), ('Dagenham Heathway', 'Dagenham East')) 1849.0
# (('Hounslow Central', 'Hounslow East'), ('Hounslow East', 'Osterley')) 15506.0
# (('Hounslow Central', 'Hounslow West'), ('Hounslow West', 'Hatton Cross')) 9620.0
# (('Golders Green', 'Brent Cross'), ('Brent Cross', 'Hendon Central')) 12632.0
# (('Golders Green', 'Hampstead'), ('Hampstead', 'Belsize Park')) 19644.0
# (('Goodge Street', 'Tottenham Court Road'), ('Tottenham Court Road', 'Bond Street')) 1026.0
# (('Goodge Street', 'Tottenham Court Road'), ('Tottenham Court Road', 'Oxford Circus')) 739.0
# (('Goodge Street', 'Tottenham Court Road'), ('Tottenham Court Road', 'Leicester Square')) 2650.0
# (('Goodge Street', 'Tottenham Court Road'), ('Tottenham Court Road', 'Holborn')) 936.0
# (('Goodge Street', 'Warren Street'), ('Warren Street', 'Euston')) 5428.0
# (('Goodge Street', 'Warren Street'), ('Warren Street', 'Oxford Circus')) 751.0
# (('Northwick Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Finchley Road')) 1406.0
# (('Northwick Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'North Harrow')) 41.0
# (('Northwick Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Wembley Park')) 90.0
# (('Northwick Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'West Harrow')) 413.0
# (('Northwick Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Marylebone')) 1106.0
# (('Northwick Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Rickmansworth')) 11.0
# (('Northwick Park', 'HarrowOnTheHill'), ('HarrowOnTheHill', 'Moor Park')) 152.0
# (('Northwick Park', 'Preston Road'), ('Preston Road', 'Wembley Park')) 89.0
# (('Preston Road', 'Wembley Park'), ('Wembley Park', 'Finchley Road')) 1551.0
# (('Preston Road', 'Wembley Park'), ('Wembley Park', 'Kingsbury')) 8.0
# (('Preston Road', 'Wembley Park'), ('Wembley Park', 'HarrowOnTheHill')) 325.0
# (('Preston Road', 'Wembley Park'), ('Wembley Park', 'Neasden')) 51.0
# (('Preston Road', 'Northwick Park'), ('Northwick Park', 'HarrowOnTheHill')) 358.0
# (('Great Portland Street', 'Baker Street'), ('Baker Street', 'Finchley Road')) 13037.0
# (('Great Portland Street', 'Baker Street'), ('Baker Street', 'Bond Street')) 1271.0
# (('Great Portland Street', 'Baker Street'), ('Baker Street', 'Edgware Road (Cir)')) 40888.0
# (('Great Portland Street', 'Baker Street'), ('Baker Street', 'Marylebone')) 5798.0
# (('Great Portland Street', 'Baker Street'), ('Baker Street', "St. John's Wood")) 1130.0
# (('Great Portland Street', 'Baker Street'), ('Baker Street', "Regent's Park")) 69.0
# (('Great Portland Street', 'Euston Square'), ('Euston Square', "King's Cross St. Pancras")) 64583.0
# (('South Kenton', 'Kenton'), ('Kenton', 'Harrow & Wealdstone')) 2223.0
# (('South Kenton', 'North Wembley'), ('North Wembley', 'Wembley Central')) 4725.0
# (('Heathrow Terminal 4', 'Hatton Cross'), ('Hatton Cross', 'Hounslow West')) 1634.0
# (('Swiss Cottage', 'Finchley Road'), ('Finchley Road', 'Willesden Green')) 468.0
# (('Swiss Cottage', 'Finchley Road'), ('Finchley Road', 'Baker Street')) 2392.0
# (('Swiss Cottage', 'Finchley Road'), ('Finchley Road', 'Wembley Park')) 529.0
# (('Swiss Cottage', 'Finchley Road'), ('Finchley Road', 'HarrowOnTheHill')) 290.0
# (('Swiss Cottage', 'Finchley Road'), ('Finchley Road', 'West Hampstead')) 374.0
# (('Swiss Cottage', "St. John's Wood"), ("St. John's Wood", 'Baker Street')) 2362.0
# (('Boston Manor', 'Osterley'), ('Osterley', 'Hounslow East')) 15898.0
# (('Boston Manor', 'Northfields'), ('Northfields', 'South Ealing')) 19683.0
# (('Maida Vale', 'Warwick Avenue'), ('Warwick Avenue', 'Paddington')) 20518.0
# (('Maida Vale', 'Kilburn Park'), ('Kilburn Park', "Queen's Park")) 13370.0
# (('Leytonstone', 'Snaresbrook'), ('Snaresbrook', 'South Woodford')) 16022.0
# (('Leytonstone', 'Leyton'), ('Leyton', 'Stratford')) 38725.0
# (('Leytonstone', 'Wanstead'), ('Wanstead', 'Redbridge')) 11278.0
# (('Oval', 'Stockwell'), ('Stockwell', 'Vauxhall')) 2531.0
# (('Oval', 'Stockwell'), ('Stockwell', 'Clapham North')) 24190.0
# (('Oval', 'Stockwell'), ('Stockwell', 'Brixton')) 5042.0
# (('Oval', 'Kennington'), ('Kennington', 'Waterloo')) 20087.0
# (('Oval', 'Kennington'), ('Kennington', 'Elephant & Castle')) 15227.0
# (('Croxley', 'Moor Park'), ('Moor Park', 'HarrowOnTheHill')) 1503.0
# (('Croxley', 'Moor Park'), ('Moor Park', 'Rickmansworth')) 96.0
# (('Croxley', 'Moor Park'), ('Moor Park', 'Northwood')) 280.0
# (('Watford', 'Croxley'), ('Croxley', 'Moor Park')) 1328.0
# (('West Finchley', 'Finchley Central'), ('Finchley Central', 'Mill Hill East')) 31.0
# (('West Finchley', 'Finchley Central'), ('Finchley Central', 'East Finchley')) 6959.0
# (('West Finchley', 'Woodside Park'), ('Woodside Park', 'Totteridge & Whetstone')) 3955.0
# (('Perivale', 'Hanger Lane'), ('Hanger Lane', 'North Acton')) 10813.0
# (('Perivale', 'Greenford'), ('Greenford', 'Northolt')) 6071.0
# (('North Wembley', 'Wembley Central'), ('Wembley Central', 'Stonebridge Park')) 5254.0
# (('North Wembley', 'South Kenton'), ('South Kenton', 'Kenton')) 3232.0
# (('Ruislip Manor', 'Ruislip'), ('Ruislip', 'Ickenham')) 7218.0
# (('Ruislip Manor', 'Eastcote'), ('Eastcote', 'Rayners Lane')) 8348.0
# (('Fulham Broadway', 'West Brompton'), ('West Brompton', "Earl's Court")) 27066.0
# (('Fulham Broadway', 'West Brompton'), ('West Brompton', 'Kensington (Olympia)')) 75.0
# (('Fulham Broadway', 'Parsons Green'), ('Parsons Green', 'Putney Bridge')) 17190.0
# (('High Barnet', 'Totteridge & Whetstone'), ('Totteridge & Whetstone', 'Woodside Park')) 2467.0
# (('Chiswick Park', 'Turnham Green'), ('Turnham Green', 'Stamford Brook')) 1.0
# (('Chiswick Park', 'Turnham Green'), ('Turnham Green', 'Hammersmith (Dis)')) 280.0
# (('Chiswick Park', 'Acton Town'), ('Acton Town', 'Hammersmith (Dis)')) 269.0
# (('Chiswick Park', 'Acton Town'), ('Acton Town', 'Ealing Common')) 965.0
# (('Chiswick Park', 'Acton Town'), ('Acton Town', 'South Ealing')) 144.0
# (('Northwood', 'Moor Park'), ('Moor Park', 'HarrowOnTheHill')) 2306.0
# (('Northwood', 'Moor Park'), ('Moor Park', 'Rickmansworth')) 107.0
# (('Northwood', 'Moor Park'), ('Moor Park', 'Croxley')) 136.0
# (('Northwood', 'Northwood Hills'), ('Northwood Hills', 'Pinner')) 185.0

# %%
g = HigherOrderGraph(p, order=3, node_id=p['node_name'])
print(g)
# Out:
# HigherOrderGraph (k=3) with 1134 nodes and 1869 edges
#
# Edge attributes
# 	edge_weight		<class 'torch.Tensor'> -> torch.Size([1869])
#
# Graph attributes
# 	num_nodes		<class 'int'>
# 	node_id		<class 'list'>

# %%
p.edge_index_k(k=3).size()
# Out:
# torch.Size([2, 573765, 3])

# %%
for e in g.edges:
    print(e, g['edge_weight', e[0], e[1]].item())
# Out:
# (('Southwark', 'Waterloo', 'Embankment'), ('Waterloo', 'Embankment', 'Temple')) 7
# (('Southwark', 'Waterloo', 'Embankment'), ('Waterloo', 'Embankment', 'Charing Cross')) 147
# (('Southwark', 'Waterloo', 'Westminster'), ('Waterloo', 'Westminster', 'Green Park')) 2663
# (('Southwark', 'Waterloo', 'Westminster'), ('Waterloo', 'Westminster', "St. James's Park")) 1102
# (('Southwark', 'Waterloo', 'Lambeth North'), ('Waterloo', 'Lambeth North', 'Elephant & Castle')) 1
# (('Southwark', 'Waterloo', 'Kennington'), ('Waterloo', 'Kennington', 'Elephant & Castle')) 1
# (('Southwark', 'Waterloo', 'Kennington'), ('Waterloo', 'Kennington', 'Oval')) 604
# (('Southwark', 'London Bridge', 'Bank / Monument'), ('London Bridge', 'Bank / Monument', 'Liverpool Street')) 2271
# (('Southwark', 'London Bridge', 'Bank / Monument'), ('London Bridge', 'Bank / Monument', 'Tower Hill')) 1035
# (('Southwark', 'London Bridge', 'Bank / Monument'), ('London Bridge', 'Bank / Monument', 'Moorgate')) 129
# (('Southwark', 'London Bridge', 'Bank / Monument'), ('London Bridge', 'Bank / Monument', "St. Paul's")) 32
# (('Southwark', 'London Bridge', 'Bank / Monument'), ('London Bridge', 'Bank / Monument', 'Cannon Street')) 58
# (('Southwark', 'London Bridge', 'Bermondsey'), ('London Bridge', 'Bermondsey', 'Canada Water')) 925
# (('Southwark', 'London Bridge', 'Borough'), ('London Bridge', 'Borough', 'Elephant & Castle')) 1
# (('Waterloo', 'Southwark', 'London Bridge'), ('Southwark', 'London Bridge', 'Bank / Monument')) 3510
# (('Waterloo', 'Southwark', 'London Bridge'), ('Southwark', 'London Bridge', 'Bermondsey')) 991
# (('Waterloo', 'Southwark', 'London Bridge'), ('Southwark', 'London Bridge', 'Borough')) 51
# (('Waterloo', 'Embankment', 'Temple'), ('Embankment', 'Temple', 'Blackfriars')) 28
# (('Waterloo', 'Embankment', 'Charing Cross'), ('Embankment', 'Charing Cross', 'Piccadilly Circus')) 97
# (('Waterloo', 'Embankment', 'Charing Cross'), ('Embankment', 'Charing Cross', 'Leicester Square')) 66
# (('Waterloo', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Bond Street')) 1049
# (('Waterloo', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Piccadilly Circus')) 95
# (('Waterloo', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Oxford Circus')) 203
# (('Waterloo', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Hyde Park Corner')) 914
# (('Waterloo', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Victoria')) 1055
# (('Waterloo', 'Westminster', "St. James's Park"), ('Westminster', "St. James's Park", 'Victoria')) 1054
# (('Waterloo', 'Lambeth North', 'Elephant & Castle'), ('Lambeth North', 'Elephant & Castle', 'Borough')) 45
# (('Waterloo', 'Kennington', 'Elephant & Castle'), ('Kennington', 'Elephant & Castle', 'Borough')) 49
# (('Waterloo', 'Kennington', 'Oval'), ('Kennington', 'Oval', 'Stockwell')) 654
# (('Liverpool Street', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Southwark')) 2243
# (('Liverpool Street', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Bermondsey')) 58
# (('Liverpool Street', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Borough')) 457
# (('Liverpool Street', 'Bank / Monument', "St. Paul's"), ('Bank / Monument', "St. Paul's", 'Chancery Lane')) 2064
# (('Liverpool Street', 'Bank / Monument', 'Cannon Street'), ('Bank / Monument', 'Cannon Street', 'Mansion House')) 156
# (('Liverpool Street', 'Moorgate', 'Old Street'), ('Moorgate', 'Old Street', 'Angel')) 1638
# (('Liverpool Street', 'Moorgate', 'Barbican'), ('Moorgate', 'Barbican', 'Farringdon')) 1617
# (('Liverpool Street', 'Aldgate East', 'Whitechapel'), ('Aldgate East', 'Whitechapel', 'Stratford')) 3177
# (('Liverpool Street', 'Aldgate East', 'Whitechapel'), ('Aldgate East', 'Whitechapel', 'Stepney Green')) 145
# (('Liverpool Street', 'Tottenham Hale', 'Seven Sisters'), ('Tottenham Hale', 'Seven Sisters', 'Finsbury Park')) 479
# (('Liverpool Street', 'Tottenham Hale', 'Blackhorse Road'), ('Tottenham Hale', 'Blackhorse Road', 'Walthamstow Central')) 112
# (('Liverpool Street', 'Bethnal Green', 'Mile End'), ('Bethnal Green', 'Mile End', 'Bow Road')) 251
# (('Liverpool Street', 'Bethnal Green', 'Mile End'), ('Bethnal Green', 'Mile End', 'Stratford')) 3176
# (('Liverpool Street', 'Bethnal Green', 'Mile End'), ('Bethnal Green', 'Mile End', 'Stepney Green')) 142
# (('Bank / Monument', 'Liverpool Street', 'Aldgate East'), ('Liverpool Street', 'Aldgate East', 'Whitechapel')) 2048
# (('Bank / Monument', 'Liverpool Street', 'Tottenham Hale'), ('Liverpool Street', 'Tottenham Hale', 'Seven Sisters')) 278
# (('Bank / Monument', 'Liverpool Street', 'Tottenham Hale'), ('Liverpool Street', 'Tottenham Hale', 'Blackhorse Road')) 170
# (('Bank / Monument', 'Liverpool Street', 'Bethnal Green'), ('Liverpool Street', 'Bethnal Green', 'Mile End')) 2216
# (('Bank / Monument', 'Tower Hill', 'Aldgate East'), ('Tower Hill', 'Aldgate East', 'Whitechapel')) 2042
# (('Bank / Monument', 'Moorgate', 'Old Street'), ('Moorgate', 'Old Street', 'Angel')) 254
# (('Bank / Monument', 'Moorgate', 'Barbican'), ('Moorgate', 'Barbican', 'Farringdon')) 245
# (('Bank / Monument', 'London Bridge', 'Southwark'), ('London Bridge', 'Southwark', 'Waterloo')) 3461
# (('Bank / Monument', 'London Bridge', 'Bermondsey'), ('London Bridge', 'Bermondsey', 'Canada Water')) 212
# (('Bank / Monument', 'London Bridge', 'Borough'), ('London Bridge', 'Borough', 'Elephant & Castle')) 676
# (('Bank / Monument', "St. Paul's", 'Chancery Lane'), ("St. Paul's", 'Chancery Lane', 'Holborn')) 3185
# (('Bank / Monument', 'Cannon Street', 'Mansion House'), ('Cannon Street', 'Mansion House', 'Blackfriars')) 200
# (('Barking', 'West Ham', 'BromleyByBow'), ('West Ham', 'BromleyByBow', 'Bow Road')) 10
# (('Barking', 'West Ham', 'Stratford'), ('West Ham', 'Stratford', 'Whitechapel')) 1299
# (('Barking', 'West Ham', 'Stratford'), ('West Ham', 'Stratford', 'Leyton')) 24
# (('Barking', 'West Ham', 'Stratford'), ('West Ham', 'Stratford', 'Mile End')) 791
# (('Barking', 'West Ham', 'Canning Town'), ('West Ham', 'Canning Town', 'North Greenwich')) 279
# (('Barking', 'Upminster', 'Upminster Bridge'), ('Upminster', 'Upminster Bridge', 'Hornchurch')) 465
# (('Barking', 'Upney', 'Becontree'), ('Upney', 'Becontree', 'Dagenham Heathway')) 475
# (('West Ham', 'Barking', 'Upminster'), ('Barking', 'Upminster', 'Upminster Bridge')) 550
# (('West Ham', 'Barking', 'Upney'), ('Barking', 'Upney', 'Becontree')) 673
# (('West Ham', 'Stratford', 'Whitechapel'), ('Stratford', 'Whitechapel', 'Aldgate East')) 1992
# (('West Ham', 'Stratford', 'Whitechapel'), ('Stratford', 'Whitechapel', 'Stepney Green')) 13
# (('West Ham', 'Stratford', 'Leyton'), ('Stratford', 'Leyton', 'Leytonstone')) 112
# (('West Ham', 'Stratford', 'Mile End'), ('Stratford', 'Mile End', 'Stepney Green')) 14
# (('West Ham', 'Stratford', 'Mile End'), ('Stratford', 'Mile End', 'Bethnal Green')) 1253
# (('West Ham', 'Canning Town', 'North Greenwich'), ('Canning Town', 'North Greenwich', 'Canary Wharf')) 436
# (('Tufnell Park', 'Kentish Town', 'Camden Town'), ('Kentish Town', 'Camden Town', 'Chalk Farm')) 38
# (('Tufnell Park', 'Kentish Town', 'Camden Town'), ('Kentish Town', 'Camden Town', 'Euston')) 1329
# (('Tufnell Park', 'Kentish Town', 'Camden Town'), ('Kentish Town', 'Camden Town', 'Mornington Crescent')) 10
# (('Tufnell Park', 'Archway', 'Highgate'), ('Archway', 'Highgate', 'East Finchley')) 811
# (('Kentish Town', 'Tufnell Park', 'Archway'), ('Tufnell Park', 'Archway', 'Highgate')) 958
# (('Kentish Town', 'Camden Town', 'Chalk Farm'), ('Camden Town', 'Chalk Farm', 'Belsize Park')) 41
# (('Kentish Town', 'Camden Town', 'Euston'), ('Camden Town', 'Euston', "King's Cross St. Pancras")) 686
# (('Kentish Town', 'Camden Town', 'Euston'), ('Camden Town', 'Euston', 'Warren Street')) 850
# (('Ruislip Gardens', 'South Ruislip', 'Northolt'), ('South Ruislip', 'Northolt', 'Greenford')) 77
# (('South Ruislip', 'Northolt', 'Greenford'), ('Northolt', 'Greenford', 'Perivale')) 249
# (('Turnpike Lane', 'Manor House', 'Finsbury Park'), ('Manor House', 'Finsbury Park', 'Seven Sisters')) 291
# (('Turnpike Lane', 'Manor House', 'Finsbury Park'), ('Manor House', 'Finsbury Park', 'Highbury & Islington')) 697
# (('Turnpike Lane', 'Manor House', 'Finsbury Park'), ('Manor House', 'Finsbury Park', 'Arsenal')) 19
# (('Turnpike Lane', 'Wood Green', 'Bounds Green'), ('Wood Green', 'Bounds Green', 'Arnos Grove')) 475
# (('Manor House', 'Turnpike Lane', 'Wood Green'), ('Turnpike Lane', 'Wood Green', 'Bounds Green')) 613
# (('Manor House', 'Finsbury Park', 'Seven Sisters'), ('Finsbury Park', 'Seven Sisters', 'Tottenham Hale')) 324
# (('Manor House', 'Finsbury Park', 'Highbury & Islington'), ('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras")) 798
# (('Manor House', 'Finsbury Park', 'Arsenal'), ('Finsbury Park', 'Arsenal', 'Holloway Road')) 15
# (('Seven Sisters', 'Finsbury Park', 'Manor House'), ('Finsbury Park', 'Manor House', 'Turnpike Lane')) 290
# (('Seven Sisters', 'Finsbury Park', 'Highbury & Islington'), ('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras")) 331
# (('Seven Sisters', 'Finsbury Park', 'Arsenal'), ('Finsbury Park', 'Arsenal', 'Holloway Road')) 48
# (('Seven Sisters', 'Tottenham Hale', 'Liverpool Street'), ('Tottenham Hale', 'Liverpool Street', 'Bank / Monument')) 289
# (('Seven Sisters', 'Tottenham Hale', 'Liverpool Street'), ('Tottenham Hale', 'Liverpool Street', 'Moorgate')) 13
# (('Seven Sisters', 'Tottenham Hale', 'Liverpool Street'), ('Tottenham Hale', 'Liverpool Street', 'Aldgate East')) 113
# (('Seven Sisters', 'Tottenham Hale', 'Liverpool Street'), ('Tottenham Hale', 'Liverpool Street', 'Aldgate')) 23
# (('Seven Sisters', 'Tottenham Hale', 'Liverpool Street'), ('Tottenham Hale', 'Liverpool Street', 'Bethnal Green')) 110
# (('Seven Sisters', 'Tottenham Hale', 'Blackhorse Road'), ('Tottenham Hale', 'Blackhorse Road', 'Walthamstow Central')) 84
# (('Finsbury Park', 'Manor House', 'Turnpike Lane'), ('Manor House', 'Turnpike Lane', 'Wood Green')) 788
# (('Finsbury Park', 'Seven Sisters', 'Tottenham Hale'), ('Seven Sisters', 'Tottenham Hale', 'Liverpool Street')) 492
# (('Finsbury Park', 'Seven Sisters', 'Tottenham Hale'), ('Seven Sisters', 'Tottenham Hale', 'Blackhorse Road')) 151
# (('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras"), ('Highbury & Islington', "King's Cross St. Pancras", 'Angel')) 20
# (('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras"), ('Highbury & Islington', "King's Cross St. Pancras", 'Caledonian Road')) 12
# (('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras"), ('Highbury & Islington', "King's Cross St. Pancras", 'Euston')) 542
# (('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras"), ('Highbury & Islington', "King's Cross St. Pancras", 'Farringdon')) 20
# (('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras"), ('Highbury & Islington', "King's Cross St. Pancras", 'Russell Square')) 129
# (('Finsbury Park', 'Highbury & Islington', "King's Cross St. Pancras"), ('Highbury & Islington', "King's Cross St. Pancras", 'Euston Square')) 640
# (('Finsbury Park', 'Arsenal', 'Holloway Road'), ('Arsenal', 'Holloway Road', 'Caledonian Road')) 12
# (('Tower Hill', 'Bank / Monument', 'Liverpool Street'), ('Bank / Monument', 'Liverpool Street', 'Tottenham Hale')) 14
# (('Tower Hill', 'Bank / Monument', 'Liverpool Street'), ('Bank / Monument', 'Liverpool Street', 'Bethnal Green')) 2
# (('Tower Hill', 'Bank / Monument', 'Moorgate'), ('Bank / Monument', 'Moorgate', 'Old Street')) 29
# (('Tower Hill', 'Bank / Monument', 'Moorgate'), ('Bank / Monument', 'Moorgate', 'Barbican')) 29
# (('Tower Hill', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Southwark')) 1023
# (('Tower Hill', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Bermondsey')) 10
# (('Tower Hill', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Borough')) 171
# (('Tower Hill', 'Bank / Monument', "St. Paul's"), ('Bank / Monument', "St. Paul's", 'Chancery Lane')) 1039
# (('Tower Hill', 'Bank / Monument', 'Cannon Street'), ('Bank / Monument', 'Cannon Street', 'Mansion House')) 76
# (('Tower Hill', 'Aldgate East', 'Liverpool Street'), ('Aldgate East', 'Liverpool Street', 'Tottenham Hale')) 13
# (('Tower Hill', 'Aldgate East', 'Liverpool Street'), ('Aldgate East', 'Liverpool Street', 'Bethnal Green')) 2
# (('Tower Hill', 'Aldgate East', 'Whitechapel'), ('Aldgate East', 'Whitechapel', 'Stratford')) 1859
# (('Tower Hill', 'Aldgate East', 'Whitechapel'), ('Aldgate East', 'Whitechapel', 'Stepney Green')) 86
# (('Tower Hill', 'Aldgate', 'Liverpool Street'), ('Aldgate', 'Liverpool Street', 'Tottenham Hale')) 13
# (('Tower Hill', 'Aldgate', 'Liverpool Street'), ('Aldgate', 'Liverpool Street', 'Bethnal Green')) 2
# (('Upminster', 'Barking', 'West Ham'), ('Barking', 'West Ham', 'BromleyByBow')) 8
# (('Upminster', 'Barking', 'West Ham'), ('Barking', 'West Ham', 'Stratford')) 622
# (('Upminster', 'Barking', 'West Ham'), ('Barking', 'West Ham', 'Plaistow')) 3
# (('Upminster', 'Barking', 'West Ham'), ('Barking', 'West Ham', 'Canning Town')) 98
# (('Upminster', 'Barking', 'Upney'), ('Barking', 'Upney', 'Becontree')) 3
# (('Upminster', 'Barking', 'East Ham'), ('Barking', 'East Ham', 'Upton Park')) 4
# (('Upminster', 'Upminster Bridge', 'Hornchurch'), ('Upminster Bridge', 'Hornchurch', 'Elm Park')) 268
# (('Embankment', 'Waterloo', 'Southwark'), ('Waterloo', 'Southwark', 'London Bridge')) 271
# (('Embankment', 'Waterloo', 'Lambeth North'), ('Waterloo', 'Lambeth North', 'Elephant & Castle')) 13
# (('Embankment', 'Waterloo', 'Kennington'), ('Waterloo', 'Kennington', 'Elephant & Castle')) 13
# (('Embankment', 'Waterloo', 'Kennington'), ('Waterloo', 'Kennington', 'Oval')) 80
# (('Embankment', 'Temple', 'Blackfriars'), ('Temple', 'Blackfriars', 'Mansion House')) 198
# (('Embankment', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Bond Street')) 237
# (('Embankment', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Oxford Circus')) 70
# (('Embankment', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Hyde Park Corner')) 112
# (('Embankment', 'Westminster', 'Green Park'), ('Westminster', 'Green Park', 'Victoria')) 125
# (('Embankment', 'Westminster', "St. James's Park"), ('Westminster', "St. James's Park", 'Victoria')) 125
# (('Embankment', 'Charing Cross', 'Piccadilly Circus'), ('Charing Cross', 'Piccadilly Circus', 'Oxford Circus')) 73
# (('Embankment', 'Charing Cross', 'Leicester Square'), ('Charing Cross', 'Leicester Square', 'Tottenham Court Road')) 40
# (('Embankment', 'Charing Cross', 'Leicester Square'), ('Charing Cross', 'Leicester Square', 'Covent Garden')) 41
# (('Temple', 'Embankment', 'Waterloo'), ('Embankment', 'Waterloo', 'Southwark')) 4
# (('Temple', 'Embankment', 'Waterloo'), ('Embankment', 'Waterloo', 'Lambeth North')) 4
# (('Temple', 'Embankment', 'Waterloo'), ('Embankment', 'Waterloo', 'Kennington')) 33
# (('Temple', 'Embankment', 'Westminster'), ('Embankment', 'Westminster', 'Green Park')) 381
# (('Temple', 'Embankment', 'Westminster'), ('Embankment', 'Westminster', "St. James's Park")) 102
# (('Temple', 'Embankment', 'Charing Cross'), ('Embankment', 'Charing Cross', 'Piccadilly Circus')) 41
# (('Temple', 'Embankment', 'Charing Cross'), ('Embankment', 'Charing Cross', 'Leicester Square')) 13
# (('Temple', 'Blackfriars', 'Mansion House'), ('Blackfriars', 'Mansion House', 'Cannon Street')) 145
# (('Finchley Road', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Marble Arch')) 30
# (('Finchley Road', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Green Park')) 877
# (('Finchley Road', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Oxford Circus')) 133
# (('Finchley Road', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Tottenham Court Road')) 684
# (('Finchley Road', 'Baker Street', 'Edgware Road (Cir)'), ('Baker Street', 'Edgware Road (Cir)', 'Paddington')) 213
# (('Finchley Road', 'Baker Street', 'Marylebone'), ('Baker Street', 'Marylebone', 'Edgware Road (Bak)')) 6
# (('Finchley Road', 'Baker Street', "Regent's Park"), ('Baker Street', "Regent's Park", 'Oxford Circus')) 136
# (('Finchley Road', 'Baker Street', 'Great Portland Street'), ('Baker Street', 'Great Portland Street', 'Euston Square')) 996
# (('Finchley Road', 'Wembley Park', 'Kingsbury'), ('Wembley Park', 'Kingsbury', 'Queensbury')) 256
# (('Finchley Road', 'HarrowOnTheHill', 'North Harrow'), ('HarrowOnTheHill', 'North Harrow', 'Pinner')) 115
# (('Finchley Road', 'HarrowOnTheHill', 'West Harrow'), ('HarrowOnTheHill', 'West Harrow', 'Rayners Lane')) 561
# (('Finchley Road', 'HarrowOnTheHill', 'Marylebone'), ('HarrowOnTheHill', 'Marylebone', 'Edgware Road (Bak)')) 6
# (('Finchley Road', 'HarrowOnTheHill', 'Rickmansworth'), ('HarrowOnTheHill', 'Rickmansworth', 'Chorleywood')) 171
# (('Finchley Road', 'HarrowOnTheHill', 'Moor Park'), ('HarrowOnTheHill', 'Moor Park', 'Croxley')) 98
# (('Finchley Road', 'HarrowOnTheHill', 'Moor Park'), ('HarrowOnTheHill', 'Moor Park', 'Northwood')) 113
# (('Willesden Green', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Bond Street')) 258
# (('Willesden Green', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Edgware Road (Cir)')) 62
# (('Willesden Green', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Marylebone')) 2
# (('Willesden Green', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', "St. John's Wood")) 4
# (('Willesden Green', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', "Regent's Park")) 20
# (('Willesden Green', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Great Portland Street')) 162
# (('Willesden Green', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Kingsbury')) 8
# (('Willesden Green', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Preston Road')) 2
# (('Willesden Green', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'North Harrow')) 2
# (('Willesden Green', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'West Harrow')) 9
# (('Willesden Green', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Marylebone')) 2
# (('Willesden Green', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Rickmansworth')) 3
# (('Willesden Green', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Moor Park')) 6
# (('Willesden Green', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Northwick Park')) 2
# (('Willesden Green', 'Finchley Road', 'Swiss Cottage'), ('Finchley Road', 'Swiss Cottage', "St. John's Wood")) 4
# (('Willesden Green', 'Neasden', 'Wembley Park'), ('Neasden', 'Wembley Park', 'Kingsbury')) 8
# (('Willesden Green', 'Neasden', 'Wembley Park'), ('Neasden', 'Wembley Park', 'Preston Road')) 2
# (('Angel', 'Old Street', 'Moorgate'), ('Old Street', 'Moorgate', 'Liverpool Street')) 1773
# (('Angel', 'Old Street', 'Moorgate'), ('Old Street', 'Moorgate', 'Bank / Monument')) 247
# (('Angel', 'Old Street', 'Moorgate'), ('Old Street', 'Moorgate', 'Barbican')) 1
# (('Angel', "King's Cross St. Pancras", 'Caledonian Road'), ("King's Cross St. Pancras", 'Caledonian Road', 'Holloway Road')) 13
# (('Angel', "King's Cross St. Pancras", 'Euston'), ("King's Cross St. Pancras", 'Euston', 'Camden Town')) 455
# (('Angel', "King's Cross St. Pancras", 'Euston'), ("King's Cross St. Pancras", 'Euston', 'Mornington Crescent')) 32
# (('Angel', "King's Cross St. Pancras", 'Euston'), ("King's Cross St. Pancras", 'Euston', 'Warren Street')) 123
# (('Angel', "King's Cross St. Pancras", 'Farringdon'), ("King's Cross St. Pancras", 'Farringdon', 'Barbican')) 1
# (('Angel', "King's Cross St. Pancras", 'Highbury & Islington'), ("King's Cross St. Pancras", 'Highbury & Islington', 'Finsbury Park')) 19
# (('Angel', "King's Cross St. Pancras", 'Russell Square'), ("King's Cross St. Pancras", 'Russell Square', 'Holborn')) 21
# (('Angel', "King's Cross St. Pancras", 'Euston Square'), ("King's Cross St. Pancras", 'Euston Square', 'Great Portland Street')) 1331
# (('Old Street', 'Angel', "King's Cross St. Pancras"), ('Angel', "King's Cross St. Pancras", 'Caledonian Road')) 43
# (('Old Street', 'Angel', "King's Cross St. Pancras"), ('Angel', "King's Cross St. Pancras", 'Euston')) 590
# (('Old Street', 'Angel', "King's Cross St. Pancras"), ('Angel', "King's Cross St. Pancras", 'Farringdon')) 1
# (('Old Street', 'Angel', "King's Cross St. Pancras"), ('Angel', "King's Cross St. Pancras", 'Highbury & Islington')) 22
# (('Old Street', 'Angel', "King's Cross St. Pancras"), ('Angel', "King's Cross St. Pancras", 'Russell Square')) 44
# (('Old Street', 'Angel', "King's Cross St. Pancras"), ('Angel', "King's Cross St. Pancras", 'Euston Square')) 1299
# (('Old Street', 'Moorgate', 'Liverpool Street'), ('Moorgate', 'Liverpool Street', 'Aldgate East')) 752
# (('Old Street', 'Moorgate', 'Liverpool Street'), ('Moorgate', 'Liverpool Street', 'Tottenham Hale')) 7
# (('Old Street', 'Moorgate', 'Liverpool Street'), ('Moorgate', 'Liverpool Street', 'Aldgate')) 96
# (('Old Street', 'Moorgate', 'Liverpool Street'), ('Moorgate', 'Liverpool Street', 'Bethnal Green')) 819
# (('Old Street', 'Moorgate', 'Bank / Monument'), ('Moorgate', 'Bank / Monument', 'Tower Hill')) 27
# (('Old Street', 'Moorgate', 'Bank / Monument'), ('Moorgate', 'Bank / Monument', 'London Bridge')) 208
# (('Old Street', 'Moorgate', 'Bank / Monument'), ('Moorgate', 'Bank / Monument', "St. Paul's")) 3
# (('Old Street', 'Moorgate', 'Bank / Monument'), ('Moorgate', 'Bank / Monument', 'Cannon Street')) 26
# (('Old Street', 'Moorgate', 'Barbican'), ('Moorgate', 'Barbican', 'Farringdon')) 1
# (('Holland Park', 'Notting Hill Gate', 'Bayswater'), ('Notting Hill Gate', 'Bayswater', 'Paddington')) 95
# (('Holland Park', 'Notting Hill Gate', 'Queensway'), ('Notting Hill Gate', 'Queensway', 'Lancaster Gate')) 318
# (('Holland Park', 'Notting Hill Gate', 'High Street Kensington'), ('Notting Hill Gate', 'High Street Kensington', "Earl's Court")) 56
# (('Holland Park', 'Notting Hill Gate', 'High Street Kensington'), ('Notting Hill Gate', 'High Street Kensington', 'Gloucester Road')) 62
# (('Holland Park', "Shepherd's Bush (Cen)", 'White City'), ("Shepherd's Bush (Cen)", 'White City', 'East Acton')) 80
# (('Notting Hill Gate', 'Holland Park', "Shepherd's Bush (Cen)"), ('Holland Park', "Shepherd's Bush (Cen)", 'White City')) 268
# (('Notting Hill Gate', 'Bayswater', 'Paddington'), ('Bayswater', 'Paddington', 'Edgware Road (Cir)')) 329
# (('Notting Hill Gate', 'Bayswater', 'Paddington'), ('Bayswater', 'Paddington', 'Edgware Road (Bak)')) 106
# (('Notting Hill Gate', 'Bayswater', 'Paddington'), ('Bayswater', 'Paddington', 'Warwick Avenue')) 75
# (('Notting Hill Gate', 'Bayswater', 'Paddington'), ('Bayswater', 'Paddington', 'Royal Oak')) 40
# (('Notting Hill Gate', 'Bayswater', 'Paddington'), ('Bayswater', 'Paddington', 'Ealing Broadway')) 86
# (('Notting Hill Gate', 'Queensway', 'Lancaster Gate'), ('Queensway', 'Lancaster Gate', 'Marble Arch')) 584
# (('Notting Hill Gate', 'High Street Kensington', "Earl's Court"), ('High Street Kensington', "Earl's Court", 'West Brompton')) 371
# (('Notting Hill Gate', 'High Street Kensington', "Earl's Court"), ('High Street Kensington', "Earl's Court", 'Barons Court')) 75
# (('Notting Hill Gate', 'High Street Kensington', "Earl's Court"), ('High Street Kensington', "Earl's Court", 'West Kensington')) 33
# (('Notting Hill Gate', 'High Street Kensington', "Earl's Court"), ('High Street Kensington', "Earl's Court", 'Kensington (Olympia)')) 15
# (('Notting Hill Gate', 'High Street Kensington', 'Gloucester Road'), ('High Street Kensington', 'Gloucester Road', 'South Kensington')) 141
# (('Baker Street', 'Finchley Road', 'Willesden Green'), ('Finchley Road', 'Willesden Green', 'Kilburn')) 143
# (('Baker Street', 'Finchley Road', 'Willesden Green'), ('Finchley Road', 'Willesden Green', 'Neasden')) 94
# (('Baker Street', 'Finchley Road', 'Willesden Green'), ('Finchley Road', 'Willesden Green', 'Dollis Hill')) 98
# (('Baker Street', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Kingsbury')) 311
# (('Baker Street', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Neasden')) 92
# (('Baker Street', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Preston Road')) 78
# (('Baker Street', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'North Harrow')) 160
# (('Baker Street', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'West Harrow')) 570
# (('Baker Street', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Rickmansworth')) 225
# (('Baker Street', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Moor Park')) 229
# (('Baker Street', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Northwick Park')) 90
# (('Baker Street', 'Finchley Road', 'West Hampstead'), ('Finchley Road', 'West Hampstead', 'Kilburn')) 143
# (('Baker Street', 'Bond Street', 'Marble Arch'), ('Bond Street', 'Marble Arch', 'Lancaster Gate')) 40
# (('Baker Street', 'Bond Street', 'Green Park'), ('Bond Street', 'Green Park', 'Westminster')) 1380
# (('Baker Street', 'Bond Street', 'Green Park'), ('Bond Street', 'Green Park', 'Piccadilly Circus')) 209
# (('Baker Street', 'Bond Street', 'Green Park'), ('Bond Street', 'Green Park', 'Hyde Park Corner')) 192
# (('Baker Street', 'Bond Street', 'Green Park'), ('Bond Street', 'Green Park', 'Victoria')) 664
# (('Baker Street', 'Bond Street', 'Oxford Circus'), ('Bond Street', 'Oxford Circus', 'Piccadilly Circus')) 210
# (('Baker Street', 'Bond Street', 'Oxford Circus'), ('Bond Street', 'Oxford Circus', 'Warren Street')) 340
# (('Baker Street', 'Bond Street', 'Tottenham Court Road'), ('Bond Street', 'Tottenham Court Road', 'Leicester Square')) 258
# (('Baker Street', 'Bond Street', 'Tottenham Court Road'), ('Bond Street', 'Tottenham Court Road', 'Holborn')) 2238
# (('Baker Street', 'Bond Street', 'Tottenham Court Road'), ('Bond Street', 'Tottenham Court Road', 'Goodge Street')) 33
# (('Baker Street', 'Edgware Road (Cir)', 'Paddington'), ('Edgware Road (Cir)', 'Paddington', 'Warwick Avenue')) 922
# (('Baker Street', 'Edgware Road (Cir)', 'Paddington'), ('Edgware Road (Cir)', 'Paddington', 'Royal Oak')) 582
# (('Baker Street', 'Edgware Road (Cir)', 'Paddington'), ('Edgware Road (Cir)', 'Paddington', 'Bayswater')) 455
# (('Baker Street', 'Edgware Road (Cir)', 'Paddington'), ('Edgware Road (Cir)', 'Paddington', 'Ealing Broadway')) 3158
# (('Baker Street', 'Marylebone', 'HarrowOnTheHill'), ('Marylebone', 'HarrowOnTheHill', 'North Harrow')) 162
# (('Baker Street', 'Marylebone', 'HarrowOnTheHill'), ('Marylebone', 'HarrowOnTheHill', 'West Harrow')) 570
# (('Baker Street', 'Marylebone', 'HarrowOnTheHill'), ('Marylebone', 'HarrowOnTheHill', 'Rickmansworth')) 228
# (('Baker Street', 'Marylebone', 'HarrowOnTheHill'), ('Marylebone', 'HarrowOnTheHill', 'Moor Park')) 235
# (('Baker Street', 'Marylebone', 'HarrowOnTheHill'), ('Marylebone', 'HarrowOnTheHill', 'Northwick Park')) 91
# (('Baker Street', "Regent's Park", 'Oxford Circus'), ("Regent's Park", 'Oxford Circus', 'Piccadilly Circus')) 204
# (('Baker Street', "Regent's Park", 'Oxford Circus'), ("Regent's Park", 'Oxford Circus', 'Warren Street')) 340
# (('Baker Street', 'Great Portland Street', 'Euston Square'), ('Great Portland Street', 'Euston Square', "King's Cross St. Pancras")) 4199
# (('Bond Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Willesden Green')) 237
# (('Bond Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Wembley Park')) 335
# (('Bond Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'HarrowOnTheHill')) 817
# (('Bond Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'West Hampstead')) 145
# (('Bond Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Swiss Cottage')) 77
# (('Bond Street', 'Baker Street', 'Edgware Road (Cir)'), ('Baker Street', 'Edgware Road (Cir)', 'Paddington')) 2511
# (('Bond Street', 'Baker Street', 'Marylebone'), ('Baker Street', 'Marylebone', 'Edgware Road (Bak)')) 67
# (('Bond Street', 'Baker Street', 'Marylebone'), ('Baker Street', 'Marylebone', 'HarrowOnTheHill')) 814
# (('Bond Street', 'Baker Street', "St. John's Wood"), ('Baker Street', "St. John's Wood", 'Swiss Cottage')) 78
# (('Bond Street', 'Baker Street', 'Great Portland Street'), ('Baker Street', 'Great Portland Street', 'Euston Square')) 71
# (('Bond Street', 'Marble Arch', 'Lancaster Gate'), ('Marble Arch', 'Lancaster Gate', 'Queensway')) 705
# (('Bond Street', 'Green Park', 'Westminster'), ('Green Park', 'Westminster', 'Waterloo')) 1035
# (('Bond Street', 'Green Park', 'Westminster'), ('Green Park', 'Westminster', 'Embankment')) 290
# (('Bond Street', 'Green Park', 'Westminster'), ('Green Park', 'Westminster', "St. James's Park")) 85
# (('Bond Street', 'Green Park', 'Piccadilly Circus'), ('Green Park', 'Piccadilly Circus', 'Charing Cross')) 98
# (('Bond Street', 'Green Park', 'Hyde Park Corner'), ('Green Park', 'Hyde Park Corner', 'Knightsbridge')) 223
# (('Bond Street', 'Green Park', 'Victoria'), ('Green Park', 'Victoria', 'Pimlico')) 448
# (('Bond Street', 'Green Park', 'Victoria'), ('Green Park', 'Victoria', "St. James's Park")) 89
# (('Bond Street', 'Green Park', 'Victoria'), ('Green Park', 'Victoria', 'Sloane Square')) 200
# (('Bond Street', 'Oxford Circus', 'Piccadilly Circus'), ('Oxford Circus', 'Piccadilly Circus', 'Charing Cross')) 99
# (('Bond Street', 'Oxford Circus', 'Warren Street'), ('Oxford Circus', 'Warren Street', 'Euston')) 472
# (('Bond Street', 'Tottenham Court Road', 'Leicester Square'), ('Tottenham Court Road', 'Leicester Square', 'Covent Garden')) 95
# (('Bond Street', 'Tottenham Court Road', 'Leicester Square'), ('Tottenham Court Road', 'Leicester Square', 'Charing Cross')) 96
# (('Bond Street', 'Tottenham Court Road', 'Holborn'), ('Tottenham Court Road', 'Holborn', 'Covent Garden')) 98
# (('Bond Street', 'Tottenham Court Road', 'Holborn'), ('Tottenham Court Road', 'Holborn', 'Russell Square')) 204
# (('Bond Street', 'Tottenham Court Road', 'Holborn'), ('Tottenham Court Road', 'Holborn', 'Chancery Lane')) 2646
# (('Latimer Road', 'Ladbroke Grove', 'Westbourne Park'), ('Ladbroke Grove', 'Westbourne Park', 'Royal Oak')) 441
# (('Latimer Road', 'Wood Lane', "Shepherd's Bush Market"), ('Wood Lane', "Shepherd's Bush Market", 'Goldhawk Road')) 131
# (('Ladbroke Grove', 'Latimer Road', 'Wood Lane'), ('Latimer Road', 'Wood Lane', "Shepherd's Bush Market")) 237
# (('Ladbroke Grove', 'Westbourne Park', 'Royal Oak'), ('Westbourne Park', 'Royal Oak', 'Paddington')) 602
# (('North Harrow', 'Pinner', 'Northwood Hills'), ('Pinner', 'Northwood Hills', 'Northwood')) 1
# (('North Harrow', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'Willesden Green')) 3
# (('North Harrow', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'Baker Street')) 174
# (('North Harrow', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'West Hampstead')) 6
# (('North Harrow', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'Swiss Cottage')) 4
# (('North Harrow', 'HarrowOnTheHill', 'Wembley Park'), ('HarrowOnTheHill', 'Wembley Park', 'Kingsbury')) 1
# (('North Harrow', 'HarrowOnTheHill', 'Wembley Park'), ('HarrowOnTheHill', 'Wembley Park', 'Neasden')) 1
# (('North Harrow', 'HarrowOnTheHill', 'Wembley Park'), ('HarrowOnTheHill', 'Wembley Park', 'Preston Road')) 2
# (('North Harrow', 'HarrowOnTheHill', 'West Harrow'), ('HarrowOnTheHill', 'West Harrow', 'Rayners Lane')) 9
# (('North Harrow', 'HarrowOnTheHill', 'Marylebone'), ('HarrowOnTheHill', 'Marylebone', 'Baker Street')) 174
# (('North Harrow', 'HarrowOnTheHill', 'Marylebone'), ('HarrowOnTheHill', 'Marylebone', 'Edgware Road (Bak)')) 22
# (('North Harrow', 'HarrowOnTheHill', 'Rickmansworth'), ('HarrowOnTheHill', 'Rickmansworth', 'Chorleywood')) 2
# (('North Harrow', 'HarrowOnTheHill', 'Moor Park'), ('HarrowOnTheHill', 'Moor Park', 'Croxley')) 3
# (('North Harrow', 'HarrowOnTheHill', 'Moor Park'), ('HarrowOnTheHill', 'Moor Park', 'Northwood')) 1
# (('North Harrow', 'HarrowOnTheHill', 'Northwick Park'), ('HarrowOnTheHill', 'Northwick Park', 'Preston Road')) 2
# (('Pinner', 'North Harrow', 'HarrowOnTheHill'), ('North Harrow', 'HarrowOnTheHill', 'Finchley Road')) 119
# (('Pinner', 'North Harrow', 'HarrowOnTheHill'), ('North Harrow', 'HarrowOnTheHill', 'Wembley Park')) 4
# (('Pinner', 'North Harrow', 'HarrowOnTheHill'), ('North Harrow', 'HarrowOnTheHill', 'West Harrow')) 6
# (('Pinner', 'North Harrow', 'HarrowOnTheHill'), ('North Harrow', 'HarrowOnTheHill', 'Marylebone')) 122
# (('Pinner', 'North Harrow', 'HarrowOnTheHill'), ('North Harrow', 'HarrowOnTheHill', 'Rickmansworth')) 2
# (('Pinner', 'North Harrow', 'HarrowOnTheHill'), ('North Harrow', 'HarrowOnTheHill', 'Moor Park')) 3
# (('Pinner', 'North Harrow', 'HarrowOnTheHill'), ('North Harrow', 'HarrowOnTheHill', 'Northwick Park')) 3
# (('Pinner', 'Northwood Hills', 'Northwood'), ('Northwood Hills', 'Northwood', 'Moor Park')) 3
# (('Chesham', 'Chalfont & Latimer', 'Chorleywood'), ('Chalfont & Latimer', 'Chorleywood', 'Rickmansworth')) 84
# (('Chalfont & Latimer', 'Chorleywood', 'Rickmansworth'), ('Chorleywood', 'Rickmansworth', 'HarrowOnTheHill')) 385
# (('Chalfont & Latimer', 'Chorleywood', 'Rickmansworth'), ('Chorleywood', 'Rickmansworth', 'Moor Park')) 7
# (('Westminster', 'Waterloo', 'Southwark'), ('Waterloo', 'Southwark', 'London Bridge')) 3620
# (('Westminster', 'Waterloo', 'Lambeth North'), ('Waterloo', 'Lambeth North', 'Elephant & Castle')) 210
# (('Westminster', 'Waterloo', 'Kennington'), ('Waterloo', 'Kennington', 'Elephant & Castle')) 215
# (('Westminster', 'Waterloo', 'Kennington'), ('Waterloo', 'Kennington', 'Oval')) 74
# (('Westminster', 'Embankment', 'Temple'), ('Embankment', 'Temple', 'Blackfriars')) 350
# (('Westminster', 'Embankment', 'Charing Cross'), ('Embankment', 'Charing Cross', 'Leicester Square')) 4
# (('Westminster', 'Green Park', 'Bond Street'), ('Green Park', 'Bond Street', 'Baker Street')) 1323
# (('Westminster', 'Green Park', 'Bond Street'), ('Green Park', 'Bond Street', 'Marble Arch')) 106
# (('Westminster', 'Green Park', 'Bond Street'), ('Green Park', 'Bond Street', 'Tottenham Court Road')) 29
# (('Westminster', 'Green Park', 'Piccadilly Circus'), ('Green Park', 'Piccadilly Circus', 'Leicester Square')) 4
# (('Westminster', 'Green Park', 'Oxford Circus'), ('Green Park', 'Oxford Circus', 'Tottenham Court Road')) 29
# (('Westminster', 'Green Park', 'Oxford Circus'), ('Green Park', 'Oxford Circus', 'Warren Street')) 287
# (('Westminster', 'Green Park', 'Oxford Circus'), ('Green Park', 'Oxford Circus', "Regent's Park")) 15
# (('Westminster', 'Green Park', 'Hyde Park Corner'), ('Green Park', 'Hyde Park Corner', 'Knightsbridge')) 1003
# (('Westminster', 'Green Park', 'Victoria'), ('Green Park', 'Victoria', 'Pimlico')) 77
# (('Westminster', 'Green Park', 'Victoria'), ('Green Park', 'Victoria', 'Sloane Square')) 980
# (('Westminster', "St. James's Park", 'Victoria'), ("St. James's Park", 'Victoria', 'Pimlico')) 72
# (('Westminster', "St. James's Park", 'Victoria'), ("St. James's Park", 'Victoria', 'Sloane Square')) 986
# (('Turnham Green', 'Gunnersbury', 'Kew Gardens'), ('Gunnersbury', 'Kew Gardens', 'Richmond')) 292
# (('Turnham Green', 'Hammersmith (Dis)', 'Barons Court'), ('Hammersmith (Dis)', 'Barons Court', "Earl's Court")) 355
# (('Turnham Green', 'Hammersmith (Dis)', 'Barons Court'), ('Hammersmith (Dis)', 'Barons Court', 'West Kensington')) 6
# (('Turnham Green', 'Acton Town', 'Ealing Common'), ('Acton Town', 'Ealing Common', 'Ealing Broadway')) 735
# (('Turnham Green', 'Acton Town', 'Ealing Common'), ('Acton Town', 'Ealing Common', 'North Ealing')) 30
# (('Turnham Green', 'Acton Town', 'South Ealing'), ('Acton Town', 'South Ealing', 'Northfields')) 19
# (('Stamford Brook', 'Turnham Green', 'Gunnersbury'), ('Turnham Green', 'Gunnersbury', 'Kew Gardens')) 4
# (('Stamford Brook', 'Turnham Green', 'Hammersmith (Dis)'), ('Turnham Green', 'Hammersmith (Dis)', 'Barons Court')) 66
# (('Stamford Brook', 'Turnham Green', 'Acton Town'), ('Turnham Green', 'Acton Town', 'Ealing Common')) 83
# (('Stamford Brook', 'Turnham Green', 'Acton Town'), ('Turnham Green', 'Acton Town', 'South Ealing')) 5
# (('Stamford Brook', 'Ravenscourt Park', 'Hammersmith (Dis)'), ('Ravenscourt Park', 'Hammersmith (Dis)', 'Barons Court')) 62
# (('Belsize Park', 'Chalk Farm', 'Camden Town'), ('Chalk Farm', 'Camden Town', 'Kentish Town')) 36
# (('Belsize Park', 'Chalk Farm', 'Camden Town'), ('Chalk Farm', 'Camden Town', 'Euston')) 1104
# (('Belsize Park', 'Chalk Farm', 'Camden Town'), ('Chalk Farm', 'Camden Town', 'Mornington Crescent')) 8
# (('Belsize Park', 'Hampstead', 'Golders Green'), ('Hampstead', 'Golders Green', 'Brent Cross')) 605
# (('Chalk Farm', 'Belsize Park', 'Hampstead'), ('Belsize Park', 'Hampstead', 'Golders Green')) 765
# (('Chalk Farm', 'Camden Town', 'Kentish Town'), ('Camden Town', 'Kentish Town', 'Tufnell Park')) 36
# (('Chalk Farm', 'Camden Town', 'Euston'), ('Camden Town', 'Euston', "King's Cross St. Pancras")) 616
# (('Chalk Farm', 'Camden Town', 'Euston'), ('Camden Town', 'Euston', 'Warren Street')) 623
# (('Bow Road', 'BromleyByBow', 'West Ham'), ('BromleyByBow', 'West Ham', 'Barking')) 8
# (('Bow Road', 'BromleyByBow', 'West Ham'), ('BromleyByBow', 'West Ham', 'Plaistow')) 2
# (('Bow Road', 'BromleyByBow', 'West Ham'), ('BromleyByBow', 'West Ham', 'Canning Town')) 2
# (('Bow Road', 'Mile End', 'Stratford'), ('Mile End', 'Stratford', 'Whitechapel')) 3
# (('Bow Road', 'Mile End', 'Stratford'), ('Mile End', 'Stratford', 'Leyton')) 6
# (('Bow Road', 'Mile End', 'Stepney Green'), ('Mile End', 'Stepney Green', 'Whitechapel')) 3
# (('Bow Road', 'Mile End', 'Bethnal Green'), ('Mile End', 'Bethnal Green', 'Liverpool Street')) 223
# (('BromleyByBow', 'West Ham', 'Barking'), ('West Ham', 'Barking', 'Upminster')) 5
# (('BromleyByBow', 'West Ham', 'Barking'), ('West Ham', 'Barking', 'Upney')) 7
# (('BromleyByBow', 'West Ham', 'Barking'), ('West Ham', 'Barking', 'East Ham')) 2
# (('BromleyByBow', 'West Ham', 'Stratford'), ('West Ham', 'Stratford', 'Whitechapel')) 2
# (('BromleyByBow', 'West Ham', 'Stratford'), ('West Ham', 'Stratford', 'Leyton')) 6
# (('BromleyByBow', 'West Ham', 'Plaistow'), ('West Ham', 'Plaistow', 'Upton Park')) 2
# (('BromleyByBow', 'West Ham', 'Canning Town'), ('West Ham', 'Canning Town', 'North Greenwich')) 1
# (('BromleyByBow', 'Bow Road', 'Mile End'), ('Bow Road', 'Mile End', 'Stepney Green')) 1
# (('BromleyByBow', 'Bow Road', 'Mile End'), ('Bow Road', 'Mile End', 'Bethnal Green')) 85
# (('Woodford', 'Buckhurst Hill', 'Loughton'), ('Buckhurst Hill', 'Loughton', 'Debden')) 465
# (('Woodford', 'South Woodford', 'Snaresbrook'), ('South Woodford', 'Snaresbrook', 'Leytonstone')) 1594
# (('Woodford', 'Roding Valley', 'Chigwell'), ('Roding Valley', 'Chigwell', 'Grange Hill')) 261
# (('Buckhurst Hill', 'Woodford', 'South Woodford'), ('Woodford', 'South Woodford', 'Snaresbrook')) 929
# (('Buckhurst Hill', 'Woodford', 'Roding Valley'), ('Woodford', 'Roding Valley', 'Chigwell')) 6
# (('Buckhurst Hill', 'Loughton', 'Debden'), ('Loughton', 'Debden', 'Theydon Bois')) 299
# (('Hanger Lane', 'North Acton', 'East Acton'), ('North Acton', 'East Acton', 'White City')) 73
# (('Hanger Lane', 'North Acton', 'West Acton'), ('North Acton', 'West Acton', 'Ealing Broadway')) 685
# (('Hanger Lane', 'Perivale', 'Greenford'), ('Perivale', 'Greenford', 'Northolt')) 318
# (('North Acton', 'Hanger Lane', 'Perivale'), ('Hanger Lane', 'Perivale', 'Greenford')) 450
# (('North Acton', 'East Acton', 'White City'), ('East Acton', 'White City', "Shepherd's Bush (Cen)")) 82
# (('North Acton', 'West Acton', 'Ealing Broadway'), ('West Acton', 'Ealing Broadway', 'Paddington')) 965
# (('North Acton', 'West Acton', 'Ealing Broadway'), ('West Acton', 'Ealing Broadway', 'Ealing Common')) 59
# (('Vauxhall', 'Stockwell', 'Clapham North'), ('Stockwell', 'Clapham North', 'Clapham Common')) 595
# (('Vauxhall', 'Stockwell', 'Oval'), ('Stockwell', 'Oval', 'Kennington')) 156
# (('Vauxhall', 'Pimlico', 'Victoria'), ('Pimlico', 'Victoria', 'Green Park')) 840
# (('Vauxhall', 'Pimlico', 'Victoria'), ('Pimlico', 'Victoria', "St. James's Park")) 16
# (('Vauxhall', 'Pimlico', 'Victoria'), ('Pimlico', 'Victoria', 'Sloane Square')) 225
# (('Stockwell', 'Vauxhall', 'Pimlico'), ('Vauxhall', 'Pimlico', 'Victoria')) 915
# (('Stockwell', 'Clapham North', 'Clapham Common'), ('Clapham North', 'Clapham Common', 'Clapham South')) 1141
# (('Stockwell', 'Oval', 'Kennington'), ('Oval', 'Kennington', 'Waterloo')) 716
# (('Stockwell', 'Oval', 'Kennington'), ('Oval', 'Kennington', 'Elephant & Castle')) 642
# (("Shepherd's Bush (Cen)", 'Holland Park', 'Notting Hill Gate'), ('Holland Park', 'Notting Hill Gate', 'Bayswater')) 78
# (("Shepherd's Bush (Cen)", 'Holland Park', 'Notting Hill Gate'), ('Holland Park', 'Notting Hill Gate', 'Queensway')) 269
# (("Shepherd's Bush (Cen)", 'Holland Park', 'Notting Hill Gate'), ('Holland Park', 'Notting Hill Gate', 'High Street Kensington')) 110
# (("Shepherd's Bush (Cen)", 'White City', 'East Acton'), ('White City', 'East Acton', 'North Acton')) 72
# (('White City', "Shepherd's Bush (Cen)", 'Holland Park'), ("Shepherd's Bush (Cen)", 'Holland Park', 'Notting Hill Gate')) 269
# (('White City', 'East Acton', 'North Acton'), ('East Acton', 'North Acton', 'Hanger Lane')) 63
# (('White City', 'East Acton', 'North Acton'), ('East Acton', 'North Acton', 'West Acton')) 52
# (('Stratford', 'West Ham', 'Barking'), ('West Ham', 'Barking', 'Upminster')) 680
# (('Stratford', 'West Ham', 'Barking'), ('West Ham', 'Barking', 'Upney')) 745
# (('Stratford', 'West Ham', 'Barking'), ('West Ham', 'Barking', 'East Ham')) 518
# (('Stratford', 'West Ham', 'Plaistow'), ('West Ham', 'Plaistow', 'Upton Park')) 427
# (('Stratford', 'West Ham', 'Canning Town'), ('West Ham', 'Canning Town', 'North Greenwich')) 77
# (('Stratford', 'Whitechapel', 'Aldgate East'), ('Whitechapel', 'Aldgate East', 'Liverpool Street')) 3128
# (('Stratford', 'Whitechapel', 'Aldgate East'), ('Whitechapel', 'Aldgate East', 'Tower Hill')) 1872
# (('Stratford', 'Leyton', 'Leytonstone'), ('Leyton', 'Leytonstone', 'Snaresbrook')) 1840
# (('Stratford', 'Leyton', 'Leytonstone'), ('Leyton', 'Leytonstone', 'Wanstead')) 1443
# (('Stratford', 'Mile End', 'Bethnal Green'), ('Mile End', 'Bethnal Green', 'Liverpool Street')) 3149
# (('Whitechapel', 'Stratford', 'West Ham'), ('Stratford', 'West Ham', 'Barking')) 1418
# (('Whitechapel', 'Stratford', 'West Ham'), ('Stratford', 'West Ham', 'BromleyByBow')) 3
# (('Whitechapel', 'Stratford', 'West Ham'), ('Stratford', 'West Ham', 'Plaistow')) 426
# (('Whitechapel', 'Stratford', 'West Ham'), ('Stratford', 'West Ham', 'Canning Town')) 60
# (('Whitechapel', 'Stratford', 'Leyton'), ('Stratford', 'Leyton', 'Leytonstone')) 2214
# (('Whitechapel', 'Stratford', 'Mile End'), ('Stratford', 'Mile End', 'Bow Road')) 3
# (('Whitechapel', 'Stratford', 'Mile End'), ('Stratford', 'Mile End', 'Bethnal Green')) 1
# (('Whitechapel', 'Aldgate East', 'Liverpool Street'), ('Aldgate East', 'Liverpool Street', 'Bank / Monument')) 2003
# (('Whitechapel', 'Aldgate East', 'Liverpool Street'), ('Aldgate East', 'Liverpool Street', 'Moorgate')) 1362
# (('Whitechapel', 'Aldgate East', 'Liverpool Street'), ('Aldgate East', 'Liverpool Street', 'Tottenham Hale')) 112
# (('Whitechapel', 'Aldgate East', 'Liverpool Street'), ('Aldgate East', 'Liverpool Street', 'Aldgate')) 5
# (('Whitechapel', 'Aldgate East', 'Liverpool Street'), ('Aldgate East', 'Liverpool Street', 'Bethnal Green')) 1
# (('Whitechapel', 'Aldgate East', 'Tower Hill'), ('Aldgate East', 'Tower Hill', 'Bank / Monument')) 2032
# (('Whitechapel', 'Aldgate East', 'Tower Hill'), ('Aldgate East', 'Tower Hill', 'Aldgate')) 6
# (('Whitechapel', 'Stepney Green', 'Mile End'), ('Stepney Green', 'Mile End', 'Bow Road')) 3
# (('Whitechapel', 'Stepney Green', 'Mile End'), ('Stepney Green', 'Mile End', 'Bethnal Green')) 1
# (('South Woodford', 'Woodford', 'Buckhurst Hill'), ('Woodford', 'Buckhurst Hill', 'Loughton')) 671
# (('South Woodford', 'Woodford', 'Roding Valley'), ('Woodford', 'Roding Valley', 'Chigwell')) 285
# (('South Woodford', 'Snaresbrook', 'Leytonstone'), ('Snaresbrook', 'Leytonstone', 'Leyton')) 1873
# (('South Woodford', 'Snaresbrook', 'Leytonstone'), ('Snaresbrook', 'Leytonstone', 'Wanstead')) 5
# (('Snaresbrook', 'South Woodford', 'Woodford'), ('South Woodford', 'Woodford', 'Buckhurst Hill')) 825
# (('Snaresbrook', 'South Woodford', 'Woodford'), ('South Woodford', 'Woodford', 'Roding Valley')) 309
# (('Snaresbrook', 'Leytonstone', 'Leyton'), ('Leytonstone', 'Leyton', 'Stratford')) 2072
# (('Snaresbrook', 'Leytonstone', 'Wanstead'), ('Leytonstone', 'Wanstead', 'Redbridge')) 6
# (('East Acton', 'North Acton', 'Hanger Lane'), ('North Acton', 'Hanger Lane', 'Perivale')) 60
# (('East Acton', 'North Acton', 'West Acton'), ('North Acton', 'West Acton', 'Ealing Broadway')) 164
# (('East Acton', 'White City', "Shepherd's Bush (Cen)"), ('White City', "Shepherd's Bush (Cen)", 'Holland Park')) 91
# (('Moorgate', 'Liverpool Street', 'Aldgate East'), ('Liverpool Street', 'Aldgate East', 'Whitechapel')) 1397
# (('Moorgate', 'Liverpool Street', 'Tottenham Hale'), ('Liverpool Street', 'Tottenham Hale', 'Seven Sisters')) 13
# (('Moorgate', 'Liverpool Street', 'Tottenham Hale'), ('Liverpool Street', 'Tottenham Hale', 'Blackhorse Road')) 10
# (('Moorgate', 'Liverpool Street', 'Bethnal Green'), ('Liverpool Street', 'Bethnal Green', 'Mile End')) 1503
# (('Moorgate', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Southwark')) 112
# (('Moorgate', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Bermondsey')) 155
# (('Moorgate', 'Bank / Monument', 'London Bridge'), ('Bank / Monument', 'London Bridge', 'Borough')) 127
# (('Moorgate', 'Bank / Monument', "St. Paul's"), ('Bank / Monument', "St. Paul's", 'Chancery Lane')) 12
# (('Moorgate', 'Bank / Monument', 'Cannon Street'), ('Bank / Monument', 'Cannon Street', 'Mansion House')) 29
# (('Moorgate', 'Old Street', 'Angel'), ('Old Street', 'Angel', "King's Cross St. Pancras")) 1903
# (('Moorgate', 'Barbican', 'Farringdon'), ('Barbican', 'Farringdon', "King's Cross St. Pancras")) 1875
# (('Edgware Road (Cir)', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Willesden Green')) 62
# (('Edgware Road (Cir)', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Wembley Park')) 72
# (('Edgware Road (Cir)', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'HarrowOnTheHill')) 11
# (('Edgware Road (Cir)', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'West Hampstead')) 46
# (('Edgware Road (Cir)', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Swiss Cottage')) 33
# (('Edgware Road (Cir)', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Marble Arch')) 20
# (('Edgware Road (Cir)', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Green Park')) 995
# (('Edgware Road (Cir)', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Oxford Circus')) 403
# (('Edgware Road (Cir)', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Tottenham Court Road')) 1398
# (('Edgware Road (Cir)', 'Baker Street', 'Marylebone'), ('Baker Street', 'Marylebone', 'HarrowOnTheHill')) 12
# (('Edgware Road (Cir)', 'Baker Street', "St. John's Wood"), ('Baker Street', "St. John's Wood", 'Swiss Cottage')) 32
# (('Edgware Road (Cir)', 'Baker Street', "Regent's Park"), ('Baker Street', "Regent's Park", 'Oxford Circus')) 395
# (('Edgware Road (Cir)', 'Baker Street', 'Great Portland Street'), ('Baker Street', 'Great Portland Street', 'Euston Square')) 2408
# (('Edgware Road (Cir)', 'Paddington', 'Warwick Avenue'), ('Paddington', 'Warwick Avenue', 'Maida Vale')) 798
# (('Edgware Road (Cir)', 'Paddington', 'Royal Oak'), ('Paddington', 'Royal Oak', 'Westbourne Park')) 505
# (('Edgware Road (Cir)', 'Paddington', 'Bayswater'), ('Paddington', 'Bayswater', 'Notting Hill Gate')) 397
# (('Edgware Road (Cir)', 'Paddington', 'Ealing Broadway'), ('Paddington', 'Ealing Broadway', 'Ealing Common')) 2162
# ...
# (('Goodge Street', 'Tottenham Court Road', 'Leicester Square'), ('Tottenham Court Road', 'Leicester Square', 'Charing Cross')) 10
# (('Goodge Street', 'Tottenham Court Road', 'Holborn'), ('Tottenham Court Road', 'Holborn', 'Covent Garden')) 2
# (('Goodge Street', 'Tottenham Court Road', 'Holborn'), ('Tottenham Court Road', 'Holborn', 'Chancery Lane')) 55
# (('Goodge Street', 'Warren Street', 'Euston'), ('Warren Street', 'Euston', "King's Cross St. Pancras")) 10
# (('Goodge Street', 'Warren Street', 'Euston'), ('Warren Street', 'Euston', 'Camden Town')) 63
# (('Goodge Street', 'Warren Street', 'Euston'), ('Warren Street', 'Euston', 'Mornington Crescent')) 3
# (('Goodge Street', 'Warren Street', 'Oxford Circus'), ('Warren Street', 'Oxford Circus', 'Green Park')) 41
# (('Goodge Street', 'Warren Street', 'Oxford Circus'), ('Warren Street', 'Oxford Circus', 'Piccadilly Circus')) 1
# (('Northwick Park', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'Willesden Green')) 3
# (('Northwick Park', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'Baker Street')) 84
# (('Northwick Park', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'West Hampstead')) 2
# (('Northwick Park', 'HarrowOnTheHill', 'Finchley Road'), ('HarrowOnTheHill', 'Finchley Road', 'Swiss Cottage')) 2
# (('Northwick Park', 'HarrowOnTheHill', 'North Harrow'), ('HarrowOnTheHill', 'North Harrow', 'Pinner')) 4
# (('Northwick Park', 'HarrowOnTheHill', 'Wembley Park'), ('HarrowOnTheHill', 'Wembley Park', 'Kingsbury')) 2
# (('Northwick Park', 'HarrowOnTheHill', 'Wembley Park'), ('HarrowOnTheHill', 'Wembley Park', 'Neasden')) 2
# (('Northwick Park', 'HarrowOnTheHill', 'West Harrow'), ('HarrowOnTheHill', 'West Harrow', 'Rayners Lane')) 11
# (('Northwick Park', 'HarrowOnTheHill', 'Marylebone'), ('HarrowOnTheHill', 'Marylebone', 'Baker Street')) 88
# (('Northwick Park', 'HarrowOnTheHill', 'Marylebone'), ('HarrowOnTheHill', 'Marylebone', 'Edgware Road (Bak)')) 22
# (('Northwick Park', 'HarrowOnTheHill', 'Rickmansworth'), ('HarrowOnTheHill', 'Rickmansworth', 'Chorleywood')) 1
# (('Northwick Park', 'HarrowOnTheHill', 'Moor Park'), ('HarrowOnTheHill', 'Moor Park', 'Croxley')) 2
# (('Northwick Park', 'HarrowOnTheHill', 'Moor Park'), ('HarrowOnTheHill', 'Moor Park', 'Northwood')) 4
# (('Northwick Park', 'Preston Road', 'Wembley Park'), ('Preston Road', 'Wembley Park', 'Kingsbury')) 2
# (('Northwick Park', 'Preston Road', 'Wembley Park'), ('Preston Road', 'Wembley Park', 'Neasden')) 2
# (('Preston Road', 'Wembley Park', 'Finchley Road'), ('Wembley Park', 'Finchley Road', 'Willesden Green')) 2
# (('Preston Road', 'Wembley Park', 'Finchley Road'), ('Wembley Park', 'Finchley Road', 'Baker Street')) 78
# (('Preston Road', 'Wembley Park', 'Finchley Road'), ('Wembley Park', 'Finchley Road', 'West Hampstead')) 2
# (('Preston Road', 'Wembley Park', 'Finchley Road'), ('Wembley Park', 'Finchley Road', 'Swiss Cottage')) 1
# (('Preston Road', 'Wembley Park', 'Kingsbury'), ('Wembley Park', 'Kingsbury', 'Queensbury')) 1
# (('Preston Road', 'Wembley Park', 'HarrowOnTheHill'), ('Wembley Park', 'HarrowOnTheHill', 'North Harrow')) 3
# (('Preston Road', 'Wembley Park', 'HarrowOnTheHill'), ('Wembley Park', 'HarrowOnTheHill', 'West Harrow')) 6
# (('Preston Road', 'Wembley Park', 'HarrowOnTheHill'), ('Wembley Park', 'HarrowOnTheHill', 'Marylebone')) 10
# (('Preston Road', 'Wembley Park', 'HarrowOnTheHill'), ('Wembley Park', 'HarrowOnTheHill', 'Moor Park')) 2
# (('Preston Road', 'Wembley Park', 'Neasden'), ('Wembley Park', 'Neasden', 'Willesden Green')) 2
# (('Preston Road', 'Wembley Park', 'Neasden'), ('Wembley Park', 'Neasden', 'Dollis Hill')) 1
# (('Preston Road', 'Northwick Park', 'HarrowOnTheHill'), ('Northwick Park', 'HarrowOnTheHill', 'North Harrow')) 3
# (('Preston Road', 'Northwick Park', 'HarrowOnTheHill'), ('Northwick Park', 'HarrowOnTheHill', 'West Harrow')) 6
# (('Preston Road', 'Northwick Park', 'HarrowOnTheHill'), ('Northwick Park', 'HarrowOnTheHill', 'Marylebone')) 10
# (('Preston Road', 'Northwick Park', 'HarrowOnTheHill'), ('Northwick Park', 'HarrowOnTheHill', 'Rickmansworth')) 1
# (('Preston Road', 'Northwick Park', 'HarrowOnTheHill'), ('Northwick Park', 'HarrowOnTheHill', 'Moor Park')) 2
# (('Great Portland Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Willesden Green')) 133
# (('Great Portland Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Wembley Park')) 190
# (('Great Portland Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'HarrowOnTheHill')) 440
# (('Great Portland Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'West Hampstead')) 76
# (('Great Portland Street', 'Baker Street', 'Finchley Road'), ('Baker Street', 'Finchley Road', 'Swiss Cottage')) 40
# (('Great Portland Street', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Marble Arch')) 37
# (('Great Portland Street', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Green Park')) 26
# (('Great Portland Street', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Oxford Circus')) 3
# (('Great Portland Street', 'Baker Street', 'Bond Street'), ('Baker Street', 'Bond Street', 'Tottenham Court Road')) 6
# (('Great Portland Street', 'Baker Street', 'Edgware Road (Cir)'), ('Baker Street', 'Edgware Road (Cir)', 'Paddington')) 2176
# (('Great Portland Street', 'Baker Street', 'Marylebone'), ('Baker Street', 'Marylebone', 'Edgware Road (Bak)')) 41
# (('Great Portland Street', 'Baker Street', 'Marylebone'), ('Baker Street', 'Marylebone', 'HarrowOnTheHill')) 446
# (('Great Portland Street', 'Baker Street', "St. John's Wood"), ('Baker Street', "St. John's Wood", 'Swiss Cottage')) 42
# (('Great Portland Street', 'Baker Street', "Regent's Park"), ('Baker Street', "Regent's Park", 'Oxford Circus')) 3
# (('Great Portland Street', 'Euston Square', "King's Cross St. Pancras"), ('Euston Square', "King's Cross St. Pancras", 'Angel')) 1436
# (('Great Portland Street', 'Euston Square', "King's Cross St. Pancras"), ('Euston Square', "King's Cross St. Pancras", 'Caledonian Road')) 152
# (('Great Portland Street', 'Euston Square', "King's Cross St. Pancras"), ('Euston Square', "King's Cross St. Pancras", 'Euston')) 313
# (('Great Portland Street', 'Euston Square', "King's Cross St. Pancras"), ('Euston Square', "King's Cross St. Pancras", 'Farringdon')) 1452
# (('Great Portland Street', 'Euston Square', "King's Cross St. Pancras"), ('Euston Square', "King's Cross St. Pancras", 'Highbury & Islington')) 732
# (('Great Portland Street', 'Euston Square', "King's Cross St. Pancras"), ('Euston Square', "King's Cross St. Pancras", 'Russell Square')) 86
# (('South Kenton', 'North Wembley', 'Wembley Central'), ('North Wembley', 'Wembley Central', 'Stonebridge Park')) 204
# (('Heathrow Terminal 4', 'Hatton Cross', 'Hounslow West'), ('Hatton Cross', 'Hounslow West', 'Hounslow Central')) 122
# (('Swiss Cottage', 'Finchley Road', 'Willesden Green'), ('Finchley Road', 'Willesden Green', 'Kilburn')) 2
# (('Swiss Cottage', 'Finchley Road', 'Willesden Green'), ('Finchley Road', 'Willesden Green', 'Neasden')) 2
# (('Swiss Cottage', 'Finchley Road', 'Willesden Green'), ('Finchley Road', 'Willesden Green', 'Dollis Hill')) 2
# (('Swiss Cottage', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Bond Street')) 83
# (('Swiss Cottage', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Edgware Road (Cir)')) 27
# (('Swiss Cottage', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Marylebone')) 2
# (('Swiss Cottage', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', "Regent's Park")) 6
# (('Swiss Cottage', 'Finchley Road', 'Baker Street'), ('Finchley Road', 'Baker Street', 'Great Portland Street')) 61
# (('Swiss Cottage', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Kingsbury')) 8
# (('Swiss Cottage', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Neasden')) 2
# (('Swiss Cottage', 'Finchley Road', 'Wembley Park'), ('Finchley Road', 'Wembley Park', 'Preston Road')) 2
# (('Swiss Cottage', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'North Harrow')) 4
# (('Swiss Cottage', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'West Harrow')) 11
# (('Swiss Cottage', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Marylebone')) 2
# (('Swiss Cottage', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Rickmansworth')) 2
# (('Swiss Cottage', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Moor Park')) 3
# (('Swiss Cottage', 'Finchley Road', 'HarrowOnTheHill'), ('Finchley Road', 'HarrowOnTheHill', 'Northwick Park')) 1
# (('Swiss Cottage', 'Finchley Road', 'West Hampstead'), ('Finchley Road', 'West Hampstead', 'Kilburn')) 2
# (('Swiss Cottage', "St. John's Wood", 'Baker Street'), ("St. John's Wood", 'Baker Street', 'Bond Street')) 81
# (('Swiss Cottage', "St. John's Wood", 'Baker Street'), ("St. John's Wood", 'Baker Street', 'Edgware Road (Cir)')) 29
# (('Swiss Cottage', "St. John's Wood", 'Baker Street'), ("St. John's Wood", 'Baker Street', 'Marylebone')) 2
# (('Swiss Cottage', "St. John's Wood", 'Baker Street'), ("St. John's Wood", 'Baker Street', "Regent's Park")) 5
# (('Swiss Cottage', "St. John's Wood", 'Baker Street'), ("St. John's Wood", 'Baker Street', 'Great Portland Street')) 57
# (('Boston Manor', 'Osterley', 'Hounslow East'), ('Osterley', 'Hounslow East', 'Hounslow Central')) 674
# (('Boston Manor', 'Northfields', 'South Ealing'), ('Northfields', 'South Ealing', 'Acton Town')) 1170
# (('Maida Vale', 'Warwick Avenue', 'Paddington'), ('Warwick Avenue', 'Paddington', 'Edgware Road (Cir)')) 993
# (('Maida Vale', 'Warwick Avenue', 'Paddington'), ('Warwick Avenue', 'Paddington', 'Edgware Road (Bak)')) 35
# (('Maida Vale', 'Warwick Avenue', 'Paddington'), ('Warwick Avenue', 'Paddington', 'Royal Oak')) 8
# (('Maida Vale', 'Warwick Avenue', 'Paddington'), ('Warwick Avenue', 'Paddington', 'Bayswater')) 88
# (('Maida Vale', 'Warwick Avenue', 'Paddington'), ('Warwick Avenue', 'Paddington', 'Ealing Broadway')) 50
# (('Maida Vale', 'Kilburn Park', "Queen's Park"), ('Kilburn Park', "Queen's Park", 'Kensal Green')) 613
# (('Leytonstone', 'Snaresbrook', 'South Woodford'), ('Snaresbrook', 'South Woodford', 'Woodford')) 1410
# (('Leytonstone', 'Leyton', 'Stratford'), ('Leyton', 'Stratford', 'West Ham')) 82
# (('Leytonstone', 'Leyton', 'Stratford'), ('Leyton', 'Stratford', 'Whitechapel')) 2383
# (('Leytonstone', 'Leyton', 'Stratford'), ('Leyton', 'Stratford', 'Mile End')) 1502
# (('Leytonstone', 'Wanstead', 'Redbridge'), ('Wanstead', 'Redbridge', 'Gants Hill')) 1045
# (('Oval', 'Stockwell', 'Vauxhall'), ('Stockwell', 'Vauxhall', 'Pimlico')) 19
# (('Oval', 'Stockwell', 'Clapham North'), ('Stockwell', 'Clapham North', 'Clapham Common')) 756
# (('Oval', 'Kennington', 'Waterloo'), ('Kennington', 'Waterloo', 'Southwark')) 656
# (('Oval', 'Kennington', 'Waterloo'), ('Kennington', 'Waterloo', 'Embankment')) 87
# (('Oval', 'Kennington', 'Waterloo'), ('Kennington', 'Waterloo', 'Westminster')) 72
# (('Oval', 'Kennington', 'Waterloo'), ('Kennington', 'Waterloo', 'Lambeth North')) 10
# (('Oval', 'Kennington', 'Elephant & Castle'), ('Kennington', 'Elephant & Castle', 'Lambeth North')) 10
# (('Oval', 'Kennington', 'Elephant & Castle'), ('Kennington', 'Elephant & Castle', 'Borough')) 667
# (('Croxley', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Finchley Road')) 100
# (('Croxley', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'North Harrow')) 4
# (('Croxley', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Wembley Park')) 6
# (('Croxley', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'West Harrow')) 8
# (('Croxley', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Marylebone')) 114
# (('Croxley', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Northwick Park')) 4
# (('Croxley', 'Moor Park', 'Rickmansworth'), ('Moor Park', 'Rickmansworth', 'Chorleywood')) 4
# (('Croxley', 'Moor Park', 'Northwood'), ('Moor Park', 'Northwood', 'Northwood Hills')) 4
# (('Watford', 'Croxley', 'Moor Park'), ('Croxley', 'Moor Park', 'HarrowOnTheHill')) 114
# (('Watford', 'Croxley', 'Moor Park'), ('Croxley', 'Moor Park', 'Rickmansworth')) 4
# (('Watford', 'Croxley', 'Moor Park'), ('Croxley', 'Moor Park', 'Northwood')) 3
# (('West Finchley', 'Finchley Central', 'East Finchley'), ('Finchley Central', 'East Finchley', 'Highgate')) 464
# (('West Finchley', 'Woodside Park', 'Totteridge & Whetstone'), ('Woodside Park', 'Totteridge & Whetstone', 'High Barnet')) 131
# (('Perivale', 'Hanger Lane', 'North Acton'), ('Hanger Lane', 'North Acton', 'East Acton')) 69
# (('Perivale', 'Hanger Lane', 'North Acton'), ('Hanger Lane', 'North Acton', 'West Acton')) 546
# (('Perivale', 'Greenford', 'Northolt'), ('Greenford', 'Northolt', 'South Ruislip')) 191
# (('North Wembley', 'Wembley Central', 'Stonebridge Park'), ('Wembley Central', 'Stonebridge Park', 'Harlesden')) 268
# (('North Wembley', 'South Kenton', 'Kenton'), ('South Kenton', 'Kenton', 'Harrow & Wealdstone')) 118
# (('Ruislip Manor', 'Ruislip', 'Ickenham'), ('Ruislip', 'Ickenham', 'Hillingdon')) 396
# (('Ruislip Manor', 'Eastcote', 'Rayners Lane'), ('Eastcote', 'Rayners Lane', 'West Harrow')) 765
# (('Ruislip Manor', 'Eastcote', 'Rayners Lane'), ('Eastcote', 'Rayners Lane', 'South Harrow')) 55
# (('Fulham Broadway', 'West Brompton', "Earl's Court"), ('West Brompton', "Earl's Court", 'Barons Court')) 128
# (('Fulham Broadway', 'West Brompton', "Earl's Court"), ('West Brompton', "Earl's Court", 'West Kensington')) 6
# (('Fulham Broadway', 'West Brompton', "Earl's Court"), ('West Brompton', "Earl's Court", 'Gloucester Road')) 1365
# (('Fulham Broadway', 'West Brompton', "Earl's Court"), ('West Brompton', "Earl's Court", 'High Street Kensington')) 307
# (('Fulham Broadway', 'Parsons Green', 'Putney Bridge'), ('Parsons Green', 'Putney Bridge', 'East Putney')) 825
# (('High Barnet', 'Totteridge & Whetstone', 'Woodside Park'), ('Totteridge & Whetstone', 'Woodside Park', 'West Finchley')) 158
# (('Chiswick Park', 'Turnham Green', 'Stamford Brook'), ('Turnham Green', 'Stamford Brook', 'Ravenscourt Park')) 1
# (('Chiswick Park', 'Turnham Green', 'Hammersmith (Dis)'), ('Turnham Green', 'Hammersmith (Dis)', 'Barons Court')) 19
# (('Chiswick Park', 'Turnham Green', 'Hammersmith (Dis)'), ('Turnham Green', 'Hammersmith (Dis)', 'Ravenscourt Park')) 1
# (('Chiswick Park', 'Acton Town', 'Hammersmith (Dis)'), ('Acton Town', 'Hammersmith (Dis)', 'Barons Court')) 19
# (('Chiswick Park', 'Acton Town', 'Hammersmith (Dis)'), ('Acton Town', 'Hammersmith (Dis)', 'Ravenscourt Park')) 1
# (('Chiswick Park', 'Acton Town', 'Ealing Common'), ('Acton Town', 'Ealing Common', 'Ealing Broadway')) 86
# (('Chiswick Park', 'Acton Town', 'Ealing Common'), ('Acton Town', 'Ealing Common', 'North Ealing')) 3
# (('Chiswick Park', 'Acton Town', 'South Ealing'), ('Acton Town', 'South Ealing', 'Northfields')) 5
# (('Northwood', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Finchley Road')) 109
# (('Northwood', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'North Harrow')) 1
# (('Northwood', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Wembley Park')) 6
# (('Northwood', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'West Harrow')) 11
# (('Northwood', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Marylebone')) 124
# (('Northwood', 'Moor Park', 'HarrowOnTheHill'), ('Moor Park', 'HarrowOnTheHill', 'Northwick Park')) 4
# (('Northwood', 'Moor Park', 'Rickmansworth'), ('Moor Park', 'Rickmansworth', 'Chorleywood')) 3
# (('Northwood', 'Moor Park', 'Croxley'), ('Moor Park', 'Croxley', 'Watford')) 2
# (('Northwood', 'Northwood Hills', 'Pinner'), ('Northwood Hills', 'Pinner', 'North Harrow')) 1
