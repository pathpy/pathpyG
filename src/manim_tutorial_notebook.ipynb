# %%
from manim import *
from pathpyG.core.temporal_graph import TemporalGraph
from pathpyG.visualisations import plot
from matplotlib.pyplot import get_cmap
import pathpyG as pp

# %% [markdown]
# # Temporal Network Visualizations with Manim

# %% [markdown]
# Also the `plot` function with Manim as backend allows the users to use the aforementioned customization options to visualize temporal graphs, but ouputs a video, which can be exported as `.mp4`.

# %%
t = pp.TemporalGraph.from_edge_list(
        [
            ("a", "b", 1),
            ("b", "c", 5),
            ("c", "d", 9),
            ("d", "a", 9),
            ("a", "b", 10),
            ("b", "c", 10),
            ("a", "b", 8),
            ("b", "c", 13),
            ("c", "d", 17),
            ("d", "a", 19),
            ("a", "b", 20),
            ("b", "c", 18),
        ]
    )

# %%
plot(t,
     backend = 'manim', 
     node_size = 0.3, 
     edge_size = 4, 
     edge_color = ['red', 'blue'],
     node_color = 0.89,
     node_label = 'Node',
     font_size = 30)
# Out:
# 100%|██████████| 21/21 [00:06<00:00,  3.34it/s]
#                 <video width="580" height="340" controls>
#                     <source src="data:video/mp4;base64,..." type="video/mp4">
#                     Your browser does not support the video tag.
#                 </video>

# %% [markdown]
# Four additional customizations are possible with the manim backend.
# 1. Both node and edge colors can be specified for single time stamps with the `node_color_timed` and `edge_color` keyword arguments.
#
#     e.g. : `node_color_timed` = [('a', (1, 'yellow')), ('b', (2, 'blue')), ('c', (4, 0.1)), ('b', (4, (255,0,0)))], where the tuples in the list specify the colors of the nodes at a specific timestamp like this: (node_id, (timestamp, color))
#
#     e.g. : `edge_color` = {'a-b-1.0':'purple', 'd-c-4.0':'green'}, where the keys node_id_1-node_id_2-time_stamp specify the nodes and the timestamp and the values the colors
#
# 2. Additionally the user can specify after how many time steps the layout is recalculated with the Fruchtermann Rheingold algorithm based on the edges that existed in the last interval with the `dynamic_layout_interval` keyword argument.
# 3. The background color can be changed with the `background_color` keyword argument
# 4. The font size of the node labels is adjustable with the `font_size` keywork argument.

# %%
plot(t,
     backend = 'manim',
     node_size = 0.1, 
     edge_size = 4, 
     edge_color = {'a-b-1.0':'purple', 'b-c-10.0':'green'},
     node_color_timed = [('a', (1, 'yellow')), ('c', (5, (255,0,0)))],
     node_color = 'purple',
     node_label=t.mapping.node_ids.tolist(),
     font_size = 40, 
     dynamic_layout_interval = 5,
     node_opacity = 0.8)
# Out:
# 100%|██████████| 21/21 [00:07<00:00,  2.97it/s]
#                 <video width="580" height="340" controls>
#                     <source src="data:video/mp4;base64,..." type="video/mp4">
#                     Your browser does not support the video tag.
#                 </video>

# %% [markdown]
# # Netzschleuder

# %%
pp.io.read_netzschleuder_record('sp_baboons')
# Out:
# {'analyses': {'observational': {'average_degree': 139.0,
#    'degree_assortativity': 0.22707284726481872,
#    'degree_std_dev': 207.8741257923002,
#    'diameter': 4,
#    'edge_properties': [['time', 'int32_t'],
#     ['behavior', 'string'],
#     ['category', 'string'],
#     ['duration', 'int16_t'],
#     ['localization', 'string'],
#     ['point', 'bool']],
#    'edge_reciprocity': 0.9690334688770722,
#    'global_clustering': 0.8499771168375833,
#    'hashimoto_radius': 15.99573462087281,
#    'is_bipartite': False,
#    'is_directed': True,
#    'knn_proj_1': None,
#    'knn_proj_2': None,
#    'largest_component_fraction': 1.0,
#    'mixing_time': 2.2276303509602045,
#    'num_edges': 3197,
#    'num_vertices': 23,
#    'transition_gap': 0.6383251329503385,
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']]},
#   'sensor': {'average_degree': 9706.923076923076,
#    'degree_assortativity': 0.26813635369584876,
#    'degree_std_dev': 4232.922166896755,
#    'diameter': 1,
#    'edge_properties': [['time', 'int32_t']],
#    'edge_reciprocity': 1.0,
#    'global_clustering': 0.7911057195179805,
#    'hashimoto_radius': 11.000000000000004,
#    'is_bipartite': False,
#    'is_directed': False,
#    'knn_proj_1': None,
#    'knn_proj_2': None,
#    'largest_component_fraction': 1.0,
#    'mixing_time': 2.3855620934197335,
#    'num_edges': 63095,
#    'num_vertices': 13,
#    'transition_gap': 0.6575802836275799,
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']]}},
#  'bibtex': ['@article{gelardi_measuring_2020,\n  doi          = {10.1098/rspa.2019.0737},\n  url          = {https://doi.org/10.1098%2Frspa.2019.0737},\n  year         = 2020,\n  month        = apr,\n  publisher    = {The Royal Society},\n  volume       = 476,\n  number       = 2236,\n  pages        = 20190737,\n  author       = {Valeria Gelardi and Jeanne Godard and Dany\n    Paleressompoulle and Nicolas Claidiere and Alain Barrat},\n  title        = {Measuring social networks in primates: wearable\n    sensors versus direct observations},\n  journal      = {Proceedings of the Royal Society A: Mathematical,\n    Physical and Engineering Sciences},\n}'],
#  'citation': [['V. Gelardi, J. Godard, D. Paleressompoulle, N. Claidière, A. Barrat, "Measuring social networks in primates: wearable sensors vs. direct observations", Proc. R. Soc. A 476:20190737 (2020)',
#    'https://doi.org/10.1098/rspa.2019.0737']],
#  'description': 'Network of interactions between a group of 20 Guinea baboons living in an enclosure of a Primate Center in France, between June 13th 2019 and July 10th 2019. The data set contains observational and wearable sensors data.\n\nThe observational data contains all the behavioral events registered by an observer, with 8 columns:\n\n- DateTime: Time stamp of the event, namely the moment the observed behavior was registered. In case of STATE events (events with duration > 0), it refers to the beginning of the behavior\n- Actor: The name of the actor\n- Recipient:  The name of the individual the Actor is acting upon\n- Behavior:  The behavior the Actor. 14 types of behaviors are registered:’Resting’, ‘Grooming’, ‘Presenting’,’Playing with’, ‘Grunting-Lipsmacking’, ‘Supplanting’,’Threatening’, ‘Submission’, ‘Touching’, ‘Avoiding’, ‘Attacking’,’Carrying’, ‘Embracing’, ‘Mounting’, ‘Copulating’, ‘Chasing’. In addition two other categories were included: ‘Invisible’ and ‘Other’\n- Category:  The classification of the behavior. It can be ‘Affiliative’, ‘Agonistic’, ‘Other’\n- Duration:  Duration of the observed behavior. POINT events have no duration\n- Localisation:  Zone of the enclosure where the observed behavior takes place\n- Point:  indicates if the event is a POINT event (YES) or a STATE event (NO).\n\nThe sensor data contains contacts recorded in the same period by the SocioPatterns infrastructure. The proximity sensors were worn by 13 of the 20 individuals cited above.\nThe data file consists of 4 columns:\n\n- t:  time of the beginning of the contact in Epoch format (Unix timestamps)\n- i:  Name of the first individual\n- j:  Name of the second individual\n- DateTime\n\n',
#  'nets': ['observational', 'sensor'],
#  'restricted': False,
#  'tags': ['Social',
#   'Animal',
#   'Offline',
#   'Unweighted',
#   'Weighted',
#   'Temporal',
#   'Metadata'],
#  'title': "Baboons' interactions (2020)",
#  'url': 'http://www.sociopatterns.org/datasets/baboons-interactions/'}

# %%
g = pp.io.read_netzschleuder_graph('sp_baboons', 'observational', time_attr='time')
g.data
# Out:
# Mapping node attributes based on node indices in column `index`
# Data(edge_index=[2, 3197], time=[3197], num_nodes=23, node_name=[23], node__pos=[23], analyses_average_degree=139.0, analyses_degree_assortativity=0.22707284726481872, analyses_degree_std_dev=207.8741257923002, analyses_diameter=4, analyses_edge_properties=[6], analyses_edge_reciprocity=0.9690334688770722, analyses_global_clustering=0.8499771168375833, analyses_hashimoto_radius=15.99573462087281, analyses_is_bipartite=False, analyses_is_directed=True, analyses_largest_component_fraction=1.0, analyses_mixing_time=2.2276303509602045, analyses_num_edges=3197, analyses_num_vertices=23, analyses_transition_gap=0.6383251329503385, analyses_vertex_properties=[2])

# %%
 g = pp.io.read_netzschleuder_graph("ambassador", "1985_1989")
 g.edge_attrs()
# Out:
# Mapping node attributes based on node indices in column `index`
# ['edge_weight']

# %%
g.edge_attrs()
# Out:
# ['edge_weight']

# %%
print(g.data)
# Out:
# Data(edge_index=[2, 38], num_nodes=16, node_sequence=[16, 1], edge_weight=[38], node_name=[16], node__pos=[16], analyses_average_degree=2.375, analyses_degree_assortativity=-0.21483375959079365, analyses_degree_std_dev=2.2325713874364688, analyses_diameter=4, analyses_edge_properties=[1], analyses_edge_reciprocity=1.0, analyses_global_clustering=0.5909090909090909, analyses_hashimoto_radius=3.234101672403292, analyses_is_bipartite=False, analyses_is_directed=False, analyses_knn_proj_1=4.213137818367892, analyses_knn_proj_2=2.0261382617110804, analyses_largest_component_fraction=0.6875, analyses_mixing_time=3.957005459796915, analyses_num_edges=19, analyses_num_vertices=16, analyses_transition_gap=0.7766881536101464, analyses_vertex_properties=[2])

# %%
plot(
    g,
    backend="manim",
    start = 1560412158,
    end = 1560412288,
    intervals = 2,
    dynamic_layout_interval=500,
    node_color_timed = [('1', (1560412160, 'green'))] ,
    node_color={'0':'red', '1':'red'},
    edge_color=['red', 'blue'],
    node_size = 0.04,
    edge_size=0.5,
    node_label={"a": "2", "b": "?", "c": "+"},
    node_label_size=20,
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plot(
#       2     g,
#       3     backend="manim",
#       4     start = 1560412158,
#       5     end = 1560412288,
#       6     intervals = 2,
#       7     dynamic_layout_interval=500,
#       8     node_color_timed = [('1', (1560412160, 'green'))] ,
#       9     node_color={'0':'red', '1':'red'},
#      10     edge_color=['red', 'blue'],
#      11     node_size = 0.04,
#      12     edge_size=0.5,
#      13     node_label={"a": "2", "b": "?", "c": "+"},
#      14     node_label_size=20,
#      15 )
#
# File c:\Users\morit\pathpyG\src\pathpyG\visualisations\__init__.py:111, in plot(data, kind, **kwargs)
#     107         raise NotImplementedError
#     109 filename = kwargs.pop("filename", None)
# --> 111 plt = PLOT_CLASSES[kind](data, **kwargs)
#     112 if filename:
#     113     plt.save(filename, **kwargs)
#
# File c:\Users\morit\pathpyG\src\pathpyG\visualisations\network_plots.py:126, in NetworkPlot.__init__(self, network, **kwargs)
#     124 self.network = network
#     125 self.config = kwargs
# --> 126 self.generate()
#
# File c:\Users\morit\pathpyG\src\pathpyG\visualisations\network_plots.py:131, in NetworkPlot.generate(self)
#     129 """Generate the plot."""
#     130 self._compute_edge_data()
# --> 131 self._compute_node_data()
#     132 self._compute_layout()
#     133 self._cleanup_config()
#
# File c:\Users\morit\pathpyG\src\pathpyG\visualisations\network_plots.py:147, in NetworkPlot._compute_node_data(self)
#     144 categories = {a.replace("node_", "") for a in self.network.node_attrs()}.intersection(attributes)
#     146 # add node data to data dict
# --> 147 self._get_node_data(nodes, attributes, attr, categories)
#     149 # convert needed attributes to useful values
#     150 attr["color"] = self._convert_color(attr["color"], mode="node")
#
# File c:\Users\morit\pathpyG\src\pathpyG\visualisations\network_plots.py:171, in NetworkPlot._get_node_data(self, nodes, attributes, attr, categories)
#     163 def _get_node_data(
#     164     self,
#     165     nodes: dict,
#    (...)
#     168     categories: set,
#     169 ) -> None:
#     170     """Extract node data from network."""
# --> 171     for uid in self.network.nodes:
#     172         nodes[uid] = {"uid": str(uid)}
#     174         # add edge attributes if needed
#
# File c:\Users\morit\pathpyG\src\pathpyG\core\graph.py:268, in Graph.nodes(self)
#     256 @property
#     257 def nodes(self) -> list:
#     258     """
#     259     Return indices or IDs of all nodes in the graph.
#     260
#    (...)
#     266         list: list of all nodes using IDs or indices (if no mapping is used)
#     267     """
# --> 268     node_list = self.mapping.to_ids(np.arange(self.n)).tolist()
#     269     if self.order > 1:
#     270         return list(map(tuple, node_list))
#
# File c:\Users\morit\pathpyG\src\pathpyG\core\index_map.py:288, in IndexMap.to_ids(self, idxs)
#     286     if not isinstance(idxs, np.ndarray):
#     287         idxs = np.array(idxs)
# --> 288     return self.node_ids[idxs]  # type: ignore
#     289 else:
#     290     return idxs
#
# IndexError: index 11 is out of bounds for axis 0 with size 11
